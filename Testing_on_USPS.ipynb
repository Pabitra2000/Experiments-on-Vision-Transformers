# %%
import numpy as np
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt
from tqdm import tqdm, trange
import torchvision
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.nn import CrossEntropyLoss
from torch.utils.data import DataLoader

from torchvision import transforms
from torchvision.datasets.mnist import MNIST
import h5py 
from functools import reduce
np.random.seed(0)
torch.manual_seed(0)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt
from torchvision.transforms import ToTensor
import torchvision.datasets as dsets

# %%
import scipy.io
mat = scipy.io.loadmat('/content/drive/MyDrive/train_32x32.mat')

# %%
mat['y'][22]
# Out:
# array([2], dtype=uint8)

# %% [markdown]
# SVHN Data and label Creation

# %% [markdown]
# Training the ViT on SVHN dataset and using it on MNIST and USPS dataset

# %%
Data = []
Label = []
SHVN_zero = []

for i in range(mat['X'].T.shape[0]):
    a = mat['X'].T[i]
    a = np.mean(a, axis = 0)
    a = a.reshape((1, 32, 32)) 

    Data.append(a)
    Label.append(mat['y'][i])

Data = np.asarray(Data)
Label = np.asarray(Label)

Label[Label == 10] = 0

max(Label)
# Out:
# array([9], dtype=uint8)

# %%
Label.shape
# Out:
# (73257, 1)

# %%
Data[5].shape
# Out:
# (1, 32, 32)

# %%
import torch.utils as utils

train_x = torch.Tensor(Data)
train_y = torch.Tensor(Label)

print(train_x[55].shape)
SVHN_dataset = utils.data.TensorDataset(train_x, train_y)
# Out:
# torch.Size([1, 32, 32])

# %%
def patchify(images, n_patches):
    n, c, h, w = images.shape

    assert h == w, "Patchify method is implemented for square images only"

    patches = torch.zeros(n, n_patches ** 2, h * w * c // n_patches ** 2)
    patch_size = h // n_patches

    for idx, image in enumerate(images):
        for i in range(n_patches):
            for j in range(n_patches):
                patch = image[:, i * patch_size: (i + 1) * patch_size, j * patch_size: (j + 1) * patch_size]
                patches[idx, i * n_patches + j] = patch.flatten()
    return patches

# %%
def get_positional_embeddings(sequence_length, d):
    result = torch.ones(sequence_length, d)
    for i in range(sequence_length):
        for j in range(d):
            result[i][j] = np.sin(i / (10000 ** (j / d))) if j % 2 == 0 else np.cos(i / (10000 ** ((j - 1) / d)))
    return result

# %%
class MyMSA(nn.Module):
    def __init__(self, d, n_heads=2):
        super(MyMSA, self).__init__()
        self.d = d
        self.n_heads = n_heads

        assert d % n_heads == 0, f"Can't divide dimension {d} into {n_heads} heads"

        d_head = int(d / n_heads)
        self.q_mappings = nn.ModuleList([nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.k_mappings = nn.ModuleList([nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.v_mappings = nn.ModuleList([nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.d_head = d_head
        self.softmax = nn.Softmax(dim=-1)

    def forward(self, sequences):
        # Sequences has shape (N, seq_length, token_dim)
        # We go into shape    (N, seq_length, n_heads, token_dim / n_heads)
        # And come back to    (N, seq_length, item_dim)  (through concatenation)
        result = []
        for sequence in sequences:
            seq_result = []
            for head in range(self.n_heads):
                q_mapping = self.q_mappings[head]
                k_mapping = self.k_mappings[head]
                v_mapping = self.v_mappings[head]

                seq = sequence[:, head * self.d_head: (head + 1) * self.d_head]
                q, k, v = q_mapping(seq), k_mapping(seq), v_mapping(seq)

                attention = self.softmax(q @ k.T / (self.d_head ** 0.5))
                seq_result.append(attention @ v)
            result.append(torch.hstack(seq_result))

        attention = torch.cat([torch.unsqueeze(r, dim=0) for r in result])
        return attention

# %%
class MyViTBlock(nn.Module):
    def __init__(self, hidden_d, n_heads, mlp_ratio=4):
        super(MyViTBlock, self).__init__()
        self.hidden_d = hidden_d
        self.n_heads = n_heads

        self.norm1 = nn.LayerNorm(hidden_d)
        self.mhsa = MyMSA(hidden_d, n_heads)
        self.norm2 = nn.LayerNorm(hidden_d)
        self.mlp = nn.Sequential(
            nn.Linear(hidden_d, mlp_ratio * hidden_d),
            nn.GELU(),
            nn.Linear(mlp_ratio * hidden_d, hidden_d)
        )

    def forward(self, x):
        #print(x.shape) 
        out = self.mhsa(self.norm1(x))
        out = out + self.mlp(self.norm2(out))
        return out

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class MyViT(nn.Module):
    def __init__(self, chw, n_patches=7, n_blocks=2, hidden_d=16, n_heads=2, out_d=10):
        # Super constructor
        super(MyViT, self).__init__()
        
        # Attributes
        self.chw = chw # ( C , H , W )
        self.n_patches = n_patches
        self.n_blocks = n_blocks
        self.n_heads = n_heads
        self.hidden_d = hidden_d
        
        # Input and patches sizes
        assert chw[1] % n_patches == 0, "Input shape not entirely divisible by number of patches"
        assert chw[2] % n_patches == 0, "Input shape not entirely divisible by number of patches"
        self.patch_size = (chw[1] / n_patches, chw[2] / n_patches)

        # 1) Linear mapper
        self.input_d = int(chw[0] * self.patch_size[0] * self.patch_size[1])
        self.linear_mapper = nn.Linear(self.input_d, self.hidden_d)
        
        # 2) Learnable classification token
        self.class_token = nn.Parameter(torch.rand(1, self.hidden_d))
        
        # 3) Positional embedding
        self.register_buffer('positional_embeddings', get_positional_embeddings(n_patches ** 2 + 1, hidden_d), persistent=False)
        
        # 4) Transformer encoder blocks
        self.blocks = nn.ModuleList([MyViTBlock(hidden_d, n_heads) for _ in range(n_blocks)])
        
        # 5) Classification MLPk
        self.mlp = nn.Sequential(
            nn.Linear(self.hidden_d, out_d),
            nn.Softmax(dim=-1)
        )

    def forward(self, images):
        # Dividing images into patches
        n, c, h, w = images.shape
        patches = patchify(images, self.n_patches).to(self.positional_embeddings.device)
        
        # Running linear layer tokenization
        # Map the vector corresponding to each patch to the hidden size dimension
        tokens = self.linear_mapper(patches)
        
        # Adding classification token to the tokens
        tokens = torch.cat((self.class_token.expand(n, 1, -1), tokens), dim=1)
        
        # Adding positional embedding
        out = tokens + self.positional_embeddings.repeat(n, 1, 1)
        
        # Transformer Blocks
        for block in self.blocks:
            out = block(out)
            
        # Getting the classification token only
        out = out[:, 0]
        
        return self.mlp(out)

# %%
model = MyViT((1, 32, 32), n_patches=8, n_blocks=2, hidden_d=16, n_heads=2, out_d=10)

# %%
import PIL
from PIL import Image
if not hasattr(PIL.Image, 'Resampling'):  # Pillow<9.0
  PIL.Image.Resampling = PIL.Image

# %%
transform = ToTensor()

transform = transforms.Compose([transforms.Resize(32), # resize to [32,32]
        transforms.ToTensor()])

train_set = MNIST(root='./../datasets', train=True, download=True, transform=transform)
train_loader = utils.data.DataLoader(SVHN_dataset,shuffle=False, batch_size=128)
train_loader2 = DataLoader(train_set, shuffle=True, batch_size=128) 

#test_loader = DataLoader(test_set, shuffle=False, batch_size=128)

# Defining model and training options
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device: ", device, f"({torch.cuda.get_device_name(device)})" if torch.cuda.is_available() else "")
model = MyViT((1, 32, 32), n_patches=8, n_blocks=2, hidden_d=16, n_heads=2, out_d=10)
N_EPOCHS = 3
LR = 0.005

# Training loop
optimizer = Adam(model.parameters(), lr=LR)
criterion = CrossEntropyLoss()
for epoch in trange(N_EPOCHS, desc="Training"):
    train_loss = 0.0
    for batch in tqdm(train_loader, desc=f"Epoch {epoch + 1} in training", leave=False):
        x, y = batch
        x, y = x, y
        y = torch.reshape(y, (-1,))
        y = y.type(torch.LongTensor)
        y_hat = model(x)
        #print(y)
        loss = criterion(y_hat, y)

        train_loss += loss.detach().cpu().item() / len(train_loader)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print(f"Epoch {epoch + 1}/{N_EPOCHS} loss: {train_loss:.2f}")


print("Entering Phas 2")

for epoch in trange(N_EPOCHS, desc="Training"):
    train_loss = 0.0
    for batch in tqdm(train_loader2, desc=f"Epoch {epoch + 1} in training", leave=False):
        x, y = batch
        x, y = x, y
        y = torch.reshape(y, (-1,))
        y = y.type(torch.LongTensor)
        y_hat = model(x)
        #print(y)
        loss = criterion(y_hat, y)

        train_loss += loss.detach().cpu().item() / len(train_loader)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print(f"Epoch {epoch + 1}/{N_EPOCHS} loss: {train_loss:.2f}")
# Out:
# Using device:  cpu
# Training:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|          | 0/573 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|          | 1/573 [00:01<18:40,  1.96s/it]
# Epoch 1 in training:   0%|          | 2/573 [00:03<18:11,  1.91s/it]
# Epoch 1 in training:   1%|          | 3/573 [00:04<13:49,  1.45s/it]
# Epoch 1 in training:   1%|          | 4/573 [00:05<10:48,  1.14s/it]
# Epoch 1 in training:   1%|          | 5/573 [00:05<08:47,  1.08it/s]
# Epoch 1 in training:   1%|          | 6/573 [00:06<07:30,  1.26it/s]
# Epoch 1 in training:   1%|          | 7/573 [00:07<06:47,  1.39it/s]
# Epoch 1 in training:   1%|▏         | 8/573 [00:07<06:18,  1.49it/s]
# Epoch 1 in training:   2%|▏         | 9/573 [00:08<05:55,  1.58it/s]
# Epoch 1 in training:   2%|▏         | 10/573 [00:08<05:44,  1.64it/s]
# Epoch 1 in training:   2%|▏         | 11/573 [00:09<05:38,  1.66it/s]
# Epoch 1 in training:   2%|▏         | 12/573 [00:09<05:31,  1.69it/s]
# Epoch 1 in training:   2%|▏         | 13/573 [00:10<05:26,  1.72it/s]
# Epoch 1 in training:   2%|▏         | 14/573 [00:11<05:22,  1.74it/s]
# Epoch 1 in training:   3%|▎         | 15/573 [00:11<05:23,  1.73it/s]
# Epoch 1 in training:   3%|▎         | 16/573 [00:12<05:18,  1.75it/s]
# Epoch 1 in training:   3%|▎         | 17/573 [00:12<05:27,  1.70it/s]
# Epoch 1 in training:   3%|▎         | 18/573 [00:13<05:25,  1.71it/s]
# Epoch 1 in training:   3%|▎         | 19/573 [00:13<05:30,  1.68it/s]
# Epoch 1 in training:   3%|▎         | 20/573 [00:14<05:26,  1.69it/s]
# Epoch 1 in training:   4%|▎         | 21/573 [00:15<05:34,  1.65it/s]
# Epoch 1 in training:   4%|▍         | 22/573 [00:15<06:04,  1.51it/s]
# Epoch 1 in training:   4%|▍         | 23/573 [00:16<06:34,  1.39it/s]
# Epoch 1 in training:   4%|▍         | 24/573 [00:17<06:52,  1.33it/s]
# Epoch 1 in training:   4%|▍         | 25/573 [00:18<07:05,  1.29it/s]
# Epoch 1 in training:   5%|▍         | 26/573 [00:19<07:14,  1.26it/s]
# Epoch 1 in training:   5%|▍         | 27/573 [00:20<06:54,  1.32it/s]
# Epoch 1 in training:   5%|▍         | 28/573 [00:20<06:23,  1.42it/s]
# Epoch 1 in training:   5%|▌         | 29/573 [00:21<06:09,  1.47it/s]
# Epoch 1 in training:   5%|▌         | 30/573 [00:21<05:55,  1.53it/s]
# Epoch 1 in training:   5%|▌         | 31/573 [00:22<05:42,  1.58it/s]
# Epoch 1 in training:   6%|▌         | 32/573 [00:22<05:30,  1.64it/s]
# Epoch 1 in training:   6%|▌         | 33/573 [00:23<05:26,  1.66it/s]
# Epoch 1 in training:   6%|▌         | 34/573 [00:24<05:18,  1.69it/s]
# Epoch 1 in training:   6%|▌         | 35/573 [00:24<05:13,  1.72it/s]
# Epoch 1 in training:   6%|▋         | 36/573 [00:25<05:11,  1.73it/s]
# Epoch 1 in training:   6%|▋         | 37/573 [00:25<05:07,  1.74it/s]
# Epoch 1 in training:   7%|▋         | 38/573 [00:26<05:04,  1.76it/s]
# Epoch 1 in training:   7%|▋         | 39/573 [00:26<05:10,  1.72it/s]
# Epoch 1 in training:   7%|▋         | 40/573 [00:27<05:12,  1.71it/s]
# Epoch 1 in training:   7%|▋         | 41/573 [00:28<05:07,  1.73it/s]
# Epoch 1 in training:   7%|▋         | 42/573 [00:28<05:01,  1.76it/s]
# Epoch 1 in training:   8%|▊         | 43/573 [00:29<04:59,  1.77it/s]
# Epoch 1 in training:   8%|▊         | 44/573 [00:29<05:02,  1.75it/s]
# Epoch 1 in training:   8%|▊         | 45/573 [00:30<05:44,  1.53it/s]
# Epoch 1 in training:   8%|▊         | 46/573 [00:31<06:14,  1.41it/s]
# Epoch 1 in training:   8%|▊         | 47/573 [00:32<06:36,  1.33it/s]
# Epoch 1 in training:   8%|▊         | 48/573 [00:33<07:00,  1.25it/s]
# Epoch 1 in training:   9%|▊         | 49/573 [00:34<07:22,  1.18it/s]
# Epoch 1 in training:   9%|▊         | 50/573 [00:34<06:44,  1.29it/s]
# Epoch 1 in training:   9%|▉         | 51/573 [00:35<06:15,  1.39it/s]
# Epoch 1 in training:   9%|▉         | 52/573 [00:35<05:54,  1.47it/s]
# Epoch 1 in training:   9%|▉         | 53/573 [00:36<05:37,  1.54it/s]
# Epoch 1 in training:   9%|▉         | 54/573 [00:37<05:25,  1.60it/s]
# Epoch 1 in training:  10%|▉         | 55/573 [00:37<05:20,  1.62it/s]
# Epoch 1 in training:  10%|▉         | 56/573 [00:38<05:09,  1.67it/s]
# Epoch 1 in training:  10%|▉         | 57/573 [00:38<05:09,  1.67it/s]
# Epoch 1 in training:  10%|█         | 58/573 [00:39<05:03,  1.70it/s]
# Epoch 1 in training:  10%|█         | 59/573 [00:40<04:59,  1.72it/s]
# Epoch 1 in training:  10%|█         | 60/573 [00:40<04:55,  1.74it/s]
# Epoch 1 in training:  11%|█         | 61/573 [00:41<04:55,  1.73it/s]
# Epoch 1 in training:  11%|█         | 62/573 [00:41<04:50,  1.76it/s]
# Epoch 1 in training:  11%|█         | 63/573 [00:42<04:50,  1.76it/s]
# Epoch 1 in training:  11%|█         | 64/573 [00:42<04:56,  1.72it/s]
# Epoch 1 in training:  11%|█▏        | 65/573 [00:43<04:53,  1.73it/s]
# Epoch 1 in training:  12%|█▏        | 66/573 [00:44<04:54,  1.72it/s]
# Epoch 1 in training:  12%|█▏        | 67/573 [00:44<05:20,  1.58it/s]
# Epoch 1 in training:  12%|█▏        | 68/573 [00:45<05:49,  1.44it/s]
# Epoch 1 in training:  12%|█▏        | 69/573 [00:46<06:11,  1.36it/s]
# Epoch 1 in training:  12%|█▏        | 70/573 [00:47<06:31,  1.29it/s]
# Epoch 1 in training:  12%|█▏        | 71/573 [00:48<06:50,  1.22it/s]
# Epoch 1 in training:  13%|█▎        | 72/573 [00:49<06:46,  1.23it/s]
# Epoch 1 in training:  13%|█▎        | 73/573 [00:49<06:06,  1.36it/s]
# Epoch 1 in training:  13%|█▎        | 74/573 [00:50<05:44,  1.45it/s]
# Epoch 1 in training:  13%|█▎        | 75/573 [00:50<05:23,  1.54it/s]
# Epoch 1 in training:  13%|█▎        | 76/573 [00:51<05:12,  1.59it/s]
# Epoch 1 in training:  13%|█▎        | 77/573 [00:51<05:05,  1.63it/s]
# Epoch 1 in training:  14%|█▎        | 78/573 [00:52<04:55,  1.67it/s]
# Epoch 1 in training:  14%|█▍        | 79/573 [00:53<04:47,  1.72it/s]
# Epoch 1 in training:  14%|█▍        | 80/573 [00:53<04:46,  1.72it/s]
# Epoch 1 in training:  14%|█▍        | 81/573 [00:54<04:43,  1.74it/s]
# Epoch 1 in training:  14%|█▍        | 82/573 [00:54<04:38,  1.76it/s]
# Epoch 1 in training:  14%|█▍        | 83/573 [00:55<04:42,  1.74it/s]
# Epoch 1 in training:  15%|█▍        | 84/573 [00:55<04:48,  1.69it/s]
# Epoch 1 in training:  15%|█▍        | 85/573 [00:56<04:47,  1.70it/s]
# Epoch 1 in training:  15%|█▌        | 86/573 [00:57<04:43,  1.72it/s]
# Epoch 1 in training:  15%|█▌        | 87/573 [00:57<04:41,  1.73it/s]
# Epoch 1 in training:  15%|█▌        | 88/573 [00:58<04:34,  1.77it/s]
# Epoch 1 in training:  16%|█▌        | 89/573 [00:58<04:38,  1.74it/s]
# Epoch 1 in training:  16%|█▌        | 90/573 [00:59<05:01,  1.60it/s]
# Epoch 1 in training:  16%|█▌        | 91/573 [01:00<05:32,  1.45it/s]
# Epoch 1 in training:  16%|█▌        | 92/573 [01:01<05:56,  1.35it/s]
# Epoch 1 in training:  16%|█▌        | 93/573 [01:02<06:15,  1.28it/s]
# Epoch 1 in training:  16%|█▋        | 94/573 [01:03<06:33,  1.22it/s]
# Epoch 1 in training:  17%|█▋        | 95/573 [01:03<06:32,  1.22it/s]
# Epoch 1 in training:  17%|█▋        | 96/573 [01:04<05:59,  1.33it/s]
# Epoch 1 in training:  17%|█▋        | 97/573 [01:05<05:34,  1.42it/s]
# Epoch 1 in training:  17%|█▋        | 98/573 [01:05<05:12,  1.52it/s]
# Epoch 1 in training:  17%|█▋        | 99/573 [01:06<04:57,  1.59it/s]
# Epoch 1 in training:  17%|█▋        | 100/573 [01:06<04:47,  1.65it/s]
# Epoch 1 in training:  18%|█▊        | 101/573 [01:07<04:40,  1.68it/s]
# Epoch 1 in training:  18%|█▊        | 102/573 [01:07<04:37,  1.70it/s]
# Epoch 1 in training:  18%|█▊        | 103/573 [01:08<04:35,  1.71it/s]
# Epoch 1 in training:  18%|█▊        | 104/573 [01:08<04:33,  1.72it/s]
# Epoch 1 in training:  18%|█▊        | 105/573 [01:09<04:27,  1.75it/s]
# Epoch 1 in training:  18%|█▊        | 106/573 [01:10<04:30,  1.73it/s]
# Epoch 1 in training:  19%|█▊        | 107/573 [01:11<05:11,  1.49it/s]
# Epoch 1 in training:  19%|█▉        | 108/573 [01:11<05:41,  1.36it/s]
# Epoch 1 in training:  19%|█▉        | 109/573 [01:12<06:20,  1.22it/s]
# Epoch 1 in training:  19%|█▉        | 110/573 [01:13<06:43,  1.15it/s]
# Epoch 1 in training:  19%|█▉        | 111/573 [01:15<07:19,  1.05it/s]
# Epoch 1 in training:  20%|█▉        | 112/573 [01:15<07:09,  1.07it/s]
# Epoch 1 in training:  20%|█▉        | 113/573 [01:16<07:10,  1.07it/s]
# Epoch 1 in training:  20%|█▉        | 114/573 [01:17<07:17,  1.05it/s]
# Epoch 1 in training:  20%|██        | 115/573 [01:18<07:17,  1.05it/s]
# Epoch 1 in training:  20%|██        | 116/573 [01:19<07:04,  1.08it/s]
# Epoch 1 in training:  20%|██        | 117/573 [01:20<06:14,  1.22it/s]
# Epoch 1 in training:  21%|██        | 118/573 [01:20<05:41,  1.33it/s]
# Epoch 1 in training:  21%|██        | 119/573 [01:21<05:18,  1.42it/s]
# Epoch 1 in training:  21%|██        | 120/573 [01:22<05:06,  1.48it/s]
# Epoch 1 in training:  21%|██        | 121/573 [01:22<04:57,  1.52it/s]
# Epoch 1 in training:  21%|██▏       | 122/573 [01:23<04:46,  1.57it/s]
# Epoch 1 in training:  21%|██▏       | 123/573 [01:23<04:43,  1.59it/s]
# Epoch 1 in training:  22%|██▏       | 124/573 [01:24<04:36,  1.63it/s]
# Epoch 1 in training:  22%|██▏       | 125/573 [01:25<04:26,  1.68it/s]
# Epoch 1 in training:  22%|██▏       | 126/573 [01:25<04:24,  1.69it/s]
# Epoch 1 in training:  22%|██▏       | 127/573 [01:26<04:19,  1.72it/s]
# Epoch 1 in training:  22%|██▏       | 128/573 [01:26<04:17,  1.73it/s]
# Epoch 1 in training:  23%|██▎       | 129/573 [01:27<04:15,  1.74it/s]
# Epoch 1 in training:  23%|██▎       | 130/573 [01:27<04:13,  1.75it/s]
# Epoch 1 in training:  23%|██▎       | 131/573 [01:28<04:11,  1.75it/s]
# Epoch 1 in training:  23%|██▎       | 132/573 [01:29<04:13,  1.74it/s]
# Epoch 1 in training:  23%|██▎       | 133/573 [01:29<04:10,  1.75it/s]
# Epoch 1 in training:  23%|██▎       | 134/573 [01:30<04:45,  1.54it/s]
# Epoch 1 in training:  24%|██▎       | 135/573 [01:31<05:13,  1.40it/s]
# Epoch 1 in training:  24%|██▎       | 136/573 [01:32<05:29,  1.33it/s]
# Epoch 1 in training:  24%|██▍       | 137/573 [01:33<05:49,  1.25it/s]
# Epoch 1 in training:  24%|██▍       | 138/573 [01:33<06:05,  1.19it/s]
# Epoch 1 in training:  24%|██▍       | 139/573 [01:34<05:48,  1.25it/s]
# Epoch 1 in training:  24%|██▍       | 140/573 [01:35<05:19,  1.35it/s]
# Epoch 1 in training:  25%|██▍       | 141/573 [01:35<04:55,  1.46it/s]
# Epoch 1 in training:  25%|██▍       | 142/573 [01:36<04:39,  1.54it/s]
# Epoch 1 in training:  25%|██▍       | 143/573 [01:36<04:31,  1.58it/s]
# Epoch 1 in training:  25%|██▌       | 144/573 [01:37<04:22,  1.64it/s]
# Epoch 1 in training:  25%|██▌       | 145/573 [01:38<04:14,  1.68it/s]
# Epoch 1 in training:  25%|██▌       | 146/573 [01:38<04:09,  1.71it/s]
# Epoch 1 in training:  26%|██▌       | 147/573 [01:39<04:09,  1.71it/s]
# Epoch 1 in training:  26%|██▌       | 148/573 [01:39<04:05,  1.73it/s]
# Epoch 1 in training:  26%|██▌       | 149/573 [01:40<04:04,  1.74it/s]
# Epoch 1 in training:  26%|██▌       | 150/573 [01:40<04:05,  1.72it/s]
# Epoch 1 in training:  26%|██▋       | 151/573 [01:41<04:08,  1.70it/s]
# Epoch 1 in training:  27%|██▋       | 152/573 [01:42<04:07,  1.70it/s]
# Epoch 1 in training:  27%|██▋       | 153/573 [01:42<04:14,  1.65it/s]
# Epoch 1 in training:  27%|██▋       | 154/573 [01:43<04:15,  1.64it/s]
# Epoch 1 in training:  27%|██▋       | 155/573 [01:44<04:17,  1.63it/s]
# Epoch 1 in training:  27%|██▋       | 156/573 [01:44<04:39,  1.49it/s]
# Epoch 1 in training:  27%|██▋       | 157/573 [01:45<05:03,  1.37it/s]
# Epoch 1 in training:  28%|██▊       | 158/573 [01:46<05:21,  1.29it/s]
# Epoch 1 in training:  28%|██▊       | 159/573 [01:47<05:34,  1.24it/s]
# Epoch 1 in training:  28%|██▊       | 160/573 [01:48<05:43,  1.20it/s]
# Epoch 1 in training:  28%|██▊       | 161/573 [01:49<05:34,  1.23it/s]
# Epoch 1 in training:  28%|██▊       | 162/573 [01:49<05:04,  1.35it/s]
# Epoch 1 in training:  28%|██▊       | 163/573 [01:50<04:45,  1.43it/s]
# Epoch 1 in training:  29%|██▊       | 164/573 [01:50<04:26,  1.53it/s]
# Epoch 1 in training:  29%|██▉       | 165/573 [01:51<04:17,  1.59it/s]
# Epoch 1 in training:  29%|██▉       | 166/573 [01:52<04:13,  1.61it/s]
# Epoch 1 in training:  29%|██▉       | 167/573 [01:52<04:07,  1.64it/s]
# Epoch 1 in training:  29%|██▉       | 168/573 [01:53<04:01,  1.68it/s]
# Epoch 1 in training:  29%|██▉       | 169/573 [01:53<04:01,  1.67it/s]
# Epoch 1 in training:  30%|██▉       | 170/573 [01:54<03:56,  1.70it/s]
# Epoch 1 in training:  30%|██▉       | 171/573 [01:54<03:55,  1.71it/s]
# Epoch 1 in training:  30%|███       | 172/573 [01:55<03:50,  1.74it/s]
# Epoch 1 in training:  30%|███       | 173/573 [01:56<03:51,  1.72it/s]
# Epoch 1 in training:  30%|███       | 174/573 [01:56<03:49,  1.74it/s]
# Epoch 1 in training:  31%|███       | 175/573 [01:57<04:08,  1.60it/s]
# Epoch 1 in training:  31%|███       | 176/573 [01:57<03:59,  1.65it/s]
# Epoch 1 in training:  31%|███       | 177/573 [01:58<03:55,  1.68it/s]
# Epoch 1 in training:  31%|███       | 178/573 [01:59<04:00,  1.64it/s]
# Epoch 1 in training:  31%|███       | 179/573 [01:59<04:26,  1.48it/s]
# Epoch 1 in training:  31%|███▏      | 180/573 [02:00<04:44,  1.38it/s]
# Epoch 1 in training:  32%|███▏      | 181/573 [02:01<04:53,  1.33it/s]
# Epoch 1 in training:  32%|███▏      | 182/573 [02:02<05:02,  1.29it/s]
# Epoch 1 in training:  32%|███▏      | 183/573 [02:03<05:18,  1.22it/s]
# Epoch 1 in training:  32%|███▏      | 184/573 [02:04<04:58,  1.30it/s]
# Epoch 1 in training:  32%|███▏      | 185/573 [02:04<04:34,  1.41it/s]
# Epoch 1 in training:  32%|███▏      | 186/573 [02:05<04:15,  1.52it/s]
# Epoch 1 in training:  33%|███▎      | 187/573 [02:05<03:59,  1.61it/s]
# Epoch 1 in training:  33%|███▎      | 188/573 [02:06<03:53,  1.65it/s]
# Epoch 1 in training:  33%|███▎      | 189/573 [02:06<03:46,  1.69it/s]
# Epoch 1 in training:  33%|███▎      | 190/573 [02:07<03:41,  1.73it/s]
# Epoch 1 in training:  33%|███▎      | 191/573 [02:07<03:37,  1.76it/s]
# Epoch 1 in training:  34%|███▎      | 192/573 [02:08<03:41,  1.72it/s]
# Epoch 1 in training:  34%|███▎      | 193/573 [02:09<03:39,  1.73it/s]
# Epoch 1 in training:  34%|███▍      | 194/573 [02:09<03:36,  1.75it/s]
# Epoch 1 in training:  34%|███▍      | 195/573 [02:10<03:36,  1.75it/s]
# Epoch 1 in training:  34%|███▍      | 196/573 [02:10<03:33,  1.76it/s]
# Epoch 1 in training:  34%|███▍      | 197/573 [02:11<03:32,  1.77it/s]
# Epoch 1 in training:  35%|███▍      | 198/573 [02:11<03:33,  1.76it/s]
# Epoch 1 in training:  35%|███▍      | 199/573 [02:12<03:34,  1.74it/s]
# Epoch 1 in training:  35%|███▍      | 200/573 [02:13<03:32,  1.75it/s]
# Epoch 1 in training:  35%|███▌      | 201/573 [02:13<03:37,  1.71it/s]
# Epoch 1 in training:  35%|███▌      | 202/573 [02:14<04:11,  1.47it/s]
# Epoch 1 in training:  35%|███▌      | 203/573 [02:15<04:37,  1.33it/s]
# Epoch 1 in training:  36%|███▌      | 204/573 [02:16<04:53,  1.26it/s]
# Epoch 1 in training:  36%|███▌      | 205/573 [02:17<05:11,  1.18it/s]
# Epoch 1 in training:  36%|███▌      | 206/573 [02:18<05:25,  1.13it/s]
# Epoch 1 in training:  36%|███▌      | 207/573 [02:18<05:00,  1.22it/s]
# Epoch 1 in training:  36%|███▋      | 208/573 [02:19<04:33,  1.34it/s]
# Epoch 1 in training:  36%|███▋      | 209/573 [02:20<04:17,  1.41it/s]
# Epoch 1 in training:  37%|███▋      | 210/573 [02:20<04:02,  1.50it/s]
# Epoch 1 in training:  37%|███▋      | 211/573 [02:21<03:48,  1.59it/s]
# Epoch 1 in training:  37%|███▋      | 212/573 [02:21<03:38,  1.65it/s]
# Epoch 1 in training:  37%|███▋      | 213/573 [02:22<03:33,  1.68it/s]
# Epoch 1 in training:  37%|███▋      | 214/573 [02:22<03:29,  1.72it/s]
# Epoch 1 in training:  38%|███▊      | 215/573 [02:23<03:24,  1.75it/s]
# Epoch 1 in training:  38%|███▊      | 216/573 [02:24<03:24,  1.75it/s]
# Epoch 1 in training:  38%|███▊      | 217/573 [02:24<03:23,  1.75it/s]
# Epoch 1 in training:  38%|███▊      | 218/573 [02:25<03:21,  1.76it/s]
# Epoch 1 in training:  38%|███▊      | 219/573 [02:25<03:22,  1.74it/s]
# Epoch 1 in training:  38%|███▊      | 220/573 [02:26<03:25,  1.72it/s]
# Epoch 1 in training:  39%|███▊      | 221/573 [02:26<03:24,  1.72it/s]
# Epoch 1 in training:  39%|███▊      | 222/573 [02:27<03:20,  1.75it/s]
# Epoch 1 in training:  39%|███▉      | 223/573 [02:28<03:18,  1.77it/s]
# Epoch 1 in training:  39%|███▉      | 224/573 [02:28<03:28,  1.67it/s]
# Epoch 1 in training:  39%|███▉      | 225/573 [02:29<03:54,  1.48it/s]
# Epoch 1 in training:  39%|███▉      | 226/573 [02:30<04:08,  1.40it/s]
# Epoch 1 in training:  40%|███▉      | 227/573 [02:31<04:18,  1.34it/s]
# Epoch 1 in training:  40%|███▉      | 228/573 [02:32<04:26,  1.30it/s]
# Epoch 1 in training:  40%|███▉      | 229/573 [02:32<04:35,  1.25it/s]
# Epoch 1 in training:  40%|████      | 230/573 [02:33<04:14,  1.35it/s]
# Epoch 1 in training:  40%|████      | 231/573 [02:34<03:55,  1.45it/s]
# Epoch 1 in training:  40%|████      | 232/573 [02:34<03:39,  1.55it/s]
# Epoch 1 in training:  41%|████      | 233/573 [02:35<03:32,  1.60it/s]
# Epoch 1 in training:  41%|████      | 234/573 [02:35<03:21,  1.68it/s]
# Epoch 1 in training:  41%|████      | 235/573 [02:36<03:15,  1.73it/s]
# Epoch 1 in training:  41%|████      | 236/573 [02:36<03:12,  1.75it/s]
# Epoch 1 in training:  41%|████▏     | 237/573 [02:37<03:11,  1.75it/s]
# Epoch 1 in training:  42%|████▏     | 238/573 [02:37<03:07,  1.79it/s]
# Epoch 1 in training:  42%|████▏     | 239/573 [02:38<03:09,  1.76it/s]
# Epoch 1 in training:  42%|████▏     | 240/573 [02:39<03:08,  1.77it/s]
# Epoch 1 in training:  42%|████▏     | 241/573 [02:39<03:06,  1.78it/s]
# Epoch 1 in training:  42%|████▏     | 242/573 [02:40<03:05,  1.78it/s]
# Epoch 1 in training:  42%|████▏     | 243/573 [02:40<03:07,  1.76it/s]
# Epoch 1 in training:  43%|████▎     | 244/573 [02:41<03:07,  1.75it/s]
# Epoch 1 in training:  43%|████▎     | 245/573 [02:41<03:07,  1.75it/s]
# Epoch 1 in training:  43%|████▎     | 246/573 [02:42<03:11,  1.70it/s]
# Epoch 1 in training:  43%|████▎     | 247/573 [02:43<03:17,  1.65it/s]
# Epoch 1 in training:  43%|████▎     | 248/573 [02:44<03:52,  1.40it/s]
# Epoch 1 in training:  43%|████▎     | 249/573 [02:45<04:13,  1.28it/s]
# Epoch 1 in training:  44%|████▎     | 250/573 [02:46<04:21,  1.24it/s]
# Epoch 1 in training:  44%|████▍     | 251/573 [02:46<04:35,  1.17it/s]
# Epoch 1 in training:  44%|████▍     | 252/573 [02:47<04:39,  1.15it/s]
# Epoch 1 in training:  44%|████▍     | 253/573 [02:48<04:12,  1.27it/s]
# Epoch 1 in training:  44%|████▍     | 254/573 [02:49<03:56,  1.35it/s]
# Epoch 1 in training:  45%|████▍     | 255/573 [02:49<03:40,  1.44it/s]
# Epoch 1 in training:  45%|████▍     | 256/573 [02:50<03:33,  1.49it/s]
# Epoch 1 in training:  45%|████▍     | 257/573 [02:50<03:29,  1.51it/s]
# Epoch 1 in training:  45%|████▌     | 258/573 [02:51<03:17,  1.59it/s]
# Epoch 1 in training:  45%|████▌     | 259/573 [02:52<03:15,  1.61it/s]
# Epoch 1 in training:  45%|████▌     | 260/573 [02:52<03:07,  1.67it/s]
# Epoch 1 in training:  46%|████▌     | 261/573 [02:53<03:04,  1.69it/s]
# Epoch 1 in training:  46%|████▌     | 262/573 [02:53<03:03,  1.69it/s]
# Epoch 1 in training:  46%|████▌     | 263/573 [02:54<02:58,  1.74it/s]
# Epoch 1 in training:  46%|████▌     | 264/573 [02:54<02:55,  1.76it/s]
# Epoch 1 in training:  46%|████▌     | 265/573 [02:55<02:52,  1.79it/s]
# Epoch 1 in training:  46%|████▋     | 266/573 [02:55<02:50,  1.80it/s]
# Epoch 1 in training:  47%|████▋     | 267/573 [02:56<02:53,  1.77it/s]
# Epoch 1 in training:  47%|████▋     | 268/573 [02:57<02:52,  1.77it/s]
# Epoch 1 in training:  47%|████▋     | 269/573 [02:57<02:49,  1.79it/s]
# Epoch 1 in training:  47%|████▋     | 270/573 [02:58<03:06,  1.63it/s]
# Epoch 1 in training:  47%|████▋     | 271/573 [02:59<03:26,  1.46it/s]
# Epoch 1 in training:  47%|████▋     | 272/573 [03:00<03:40,  1.36it/s]
# Epoch 1 in training:  48%|████▊     | 273/573 [03:01<04:08,  1.21it/s]
# Epoch 1 in training:  48%|████▊     | 274/573 [03:02<04:10,  1.20it/s]
# Epoch 1 in training:  48%|████▊     | 275/573 [03:02<04:00,  1.24it/s]
# Epoch 1 in training:  48%|████▊     | 276/573 [03:03<03:41,  1.34it/s]
# Epoch 1 in training:  48%|████▊     | 277/573 [03:03<03:24,  1.45it/s]
# Epoch 1 in training:  49%|████▊     | 278/573 [03:04<03:11,  1.54it/s]
# Epoch 1 in training:  49%|████▊     | 279/573 [03:05<03:02,  1.61it/s]
# Epoch 1 in training:  49%|████▉     | 280/573 [03:05<02:56,  1.66it/s]
# Epoch 1 in training:  49%|████▉     | 281/573 [03:06<02:53,  1.68it/s]
# Epoch 1 in training:  49%|████▉     | 282/573 [03:06<02:49,  1.71it/s]
# Epoch 1 in training:  49%|████▉     | 283/573 [03:07<02:53,  1.67it/s]
# Epoch 1 in training:  50%|████▉     | 284/573 [03:08<03:04,  1.56it/s]
# Epoch 1 in training:  50%|████▉     | 285/573 [03:08<03:23,  1.41it/s]
# Epoch 1 in training:  50%|████▉     | 286/573 [03:09<03:09,  1.52it/s]
# Epoch 1 in training:  50%|█████     | 287/573 [03:10<03:03,  1.56it/s]
# Epoch 1 in training:  50%|█████     | 288/573 [03:10<02:59,  1.59it/s]
# Epoch 1 in training:  50%|█████     | 289/573 [03:11<02:52,  1.64it/s]
# Epoch 1 in training:  51%|█████     | 290/573 [03:11<02:53,  1.63it/s]
# Epoch 1 in training:  51%|█████     | 291/573 [03:12<02:57,  1.59it/s]
# Epoch 1 in training:  51%|█████     | 292/573 [03:13<03:23,  1.38it/s]
# Epoch 1 in training:  51%|█████     | 293/573 [03:14<03:40,  1.27it/s]
# Epoch 1 in training:  51%|█████▏    | 294/573 [03:15<03:44,  1.24it/s]
# Epoch 1 in training:  51%|█████▏    | 295/573 [03:16<03:50,  1.21it/s]
# Epoch 1 in training:  52%|█████▏    | 296/573 [03:17<03:57,  1.17it/s]
# Epoch 1 in training:  52%|█████▏    | 297/573 [03:17<03:41,  1.24it/s]
# Epoch 1 in training:  52%|█████▏    | 298/573 [03:18<03:25,  1.34it/s]
# Epoch 1 in training:  52%|█████▏    | 299/573 [03:19<03:14,  1.41it/s]
# Epoch 1 in training:  52%|█████▏    | 300/573 [03:19<03:02,  1.50it/s]
# Epoch 1 in training:  53%|█████▎    | 301/573 [03:20<02:56,  1.54it/s]
# Epoch 1 in training:  53%|█████▎    | 302/573 [03:20<02:51,  1.58it/s]
# Epoch 1 in training:  53%|█████▎    | 303/573 [03:21<02:45,  1.63it/s]
# Epoch 1 in training:  53%|█████▎    | 304/573 [03:21<02:41,  1.66it/s]
# Epoch 1 in training:  53%|█████▎    | 305/573 [03:22<02:37,  1.70it/s]
# Epoch 1 in training:  53%|█████▎    | 306/573 [03:23<02:36,  1.71it/s]
# Epoch 1 in training:  54%|█████▎    | 307/573 [03:23<02:36,  1.70it/s]
# Epoch 1 in training:  54%|█████▍    | 308/573 [03:24<02:35,  1.70it/s]
# Epoch 1 in training:  54%|█████▍    | 309/573 [03:24<02:33,  1.72it/s]
# Epoch 1 in training:  54%|█████▍    | 310/573 [03:25<02:30,  1.75it/s]
# Epoch 1 in training:  54%|█████▍    | 311/573 [03:25<02:30,  1.74it/s]
# Epoch 1 in training:  54%|█████▍    | 312/573 [03:26<02:26,  1.78it/s]
# Epoch 1 in training:  55%|█████▍    | 313/573 [03:27<02:26,  1.77it/s]
# Epoch 1 in training:  55%|█████▍    | 314/573 [03:27<02:40,  1.61it/s]
# Epoch 1 in training:  55%|█████▍    | 315/573 [03:28<02:58,  1.44it/s]
# Epoch 1 in training:  55%|█████▌    | 316/573 [03:29<03:10,  1.35it/s]
# Epoch 1 in training:  55%|█████▌    | 317/573 [03:30<03:15,  1.31it/s]
# Epoch 1 in training:  55%|█████▌    | 318/573 [03:31<03:18,  1.28it/s]
# Epoch 1 in training:  56%|█████▌    | 319/573 [03:31<03:19,  1.27it/s]
# Epoch 1 in training:  56%|█████▌    | 320/573 [03:32<03:01,  1.39it/s]
# Epoch 1 in training:  56%|█████▌    | 321/573 [03:33<02:49,  1.48it/s]
# Epoch 1 in training:  56%|█████▌    | 322/573 [03:33<02:42,  1.54it/s]
# Epoch 1 in training:  56%|█████▋    | 323/573 [03:34<02:37,  1.58it/s]
# Epoch 1 in training:  57%|█████▋    | 324/573 [03:34<02:31,  1.64it/s]
# Epoch 1 in training:  57%|█████▋    | 325/573 [03:35<02:29,  1.66it/s]
# Epoch 1 in training:  57%|█████▋    | 326/573 [03:35<02:25,  1.69it/s]
# Epoch 1 in training:  57%|█████▋    | 327/573 [03:36<02:23,  1.71it/s]
# Epoch 1 in training:  57%|█████▋    | 328/573 [03:37<02:23,  1.71it/s]
# Epoch 1 in training:  57%|█████▋    | 329/573 [03:37<02:22,  1.72it/s]
# Epoch 1 in training:  58%|█████▊    | 330/573 [03:38<02:19,  1.75it/s]
# Epoch 1 in training:  58%|█████▊    | 331/573 [03:38<02:18,  1.75it/s]
# Epoch 1 in training:  58%|█████▊    | 332/573 [03:39<02:17,  1.76it/s]
# Epoch 1 in training:  58%|█████▊    | 333/573 [03:39<02:15,  1.77it/s]
# Epoch 1 in training:  58%|█████▊    | 334/573 [03:40<02:15,  1.76it/s]
# Epoch 1 in training:  58%|█████▊    | 335/573 [03:41<02:15,  1.75it/s]
# Epoch 1 in training:  59%|█████▊    | 336/573 [03:41<02:15,  1.75it/s]
# Epoch 1 in training:  59%|█████▉    | 337/573 [03:42<02:28,  1.59it/s]
# Epoch 1 in training:  59%|█████▉    | 338/573 [03:43<02:44,  1.43it/s]
# Epoch 1 in training:  59%|█████▉    | 339/573 [03:44<02:56,  1.32it/s]
# Epoch 1 in training:  59%|█████▉    | 340/573 [03:45<03:00,  1.29it/s]
# Epoch 1 in training:  60%|█████▉    | 341/573 [03:45<03:04,  1.26it/s]
# Epoch 1 in training:  60%|█████▉    | 342/573 [03:46<03:02,  1.26it/s]
# Epoch 1 in training:  60%|█████▉    | 343/573 [03:47<02:45,  1.39it/s]
# Epoch 1 in training:  60%|██████    | 344/573 [03:47<02:34,  1.48it/s]
# Epoch 1 in training:  60%|██████    | 345/573 [03:48<02:26,  1.55it/s]
# Epoch 1 in training:  60%|██████    | 346/573 [03:48<02:21,  1.60it/s]
# Epoch 1 in training:  61%|██████    | 347/573 [03:49<02:16,  1.66it/s]
# Epoch 1 in training:  61%|██████    | 348/573 [03:50<02:15,  1.66it/s]
# Epoch 1 in training:  61%|██████    | 349/573 [03:50<02:10,  1.71it/s]
# Epoch 1 in training:  61%|██████    | 350/573 [03:51<02:10,  1.71it/s]
# Epoch 1 in training:  61%|██████▏   | 351/573 [03:51<02:07,  1.74it/s]
# Epoch 1 in training:  61%|██████▏   | 352/573 [03:52<02:06,  1.74it/s]
# Epoch 1 in training:  62%|██████▏   | 353/573 [03:52<02:05,  1.75it/s]
# Epoch 1 in training:  62%|██████▏   | 354/573 [03:53<02:03,  1.78it/s]
# Epoch 1 in training:  62%|██████▏   | 355/573 [03:53<02:02,  1.78it/s]
# Epoch 1 in training:  62%|██████▏   | 356/573 [03:54<02:00,  1.81it/s]
# Epoch 1 in training:  62%|██████▏   | 357/573 [03:55<01:59,  1.82it/s]
# Epoch 1 in training:  62%|██████▏   | 358/573 [03:55<01:59,  1.81it/s]
# Epoch 1 in training:  63%|██████▎   | 359/573 [03:56<01:58,  1.80it/s]
# Epoch 1 in training:  63%|██████▎   | 360/573 [03:56<02:02,  1.74it/s]
# Epoch 1 in training:  63%|██████▎   | 361/573 [03:57<02:16,  1.55it/s]
# Epoch 1 in training:  63%|██████▎   | 362/573 [03:58<02:29,  1.41it/s]
# Epoch 1 in training:  63%|██████▎   | 363/573 [03:59<02:36,  1.35it/s]
# Epoch 1 in training:  64%|██████▎   | 364/573 [04:00<02:38,  1.32it/s]
# Epoch 1 in training:  64%|██████▎   | 365/573 [04:00<02:44,  1.26it/s]
# Epoch 1 in training:  64%|██████▍   | 366/573 [04:01<02:32,  1.35it/s]
# Epoch 1 in training:  64%|██████▍   | 367/573 [04:02<02:19,  1.48it/s]
# Epoch 1 in training:  64%|██████▍   | 368/573 [04:02<02:12,  1.55it/s]
# Epoch 1 in training:  64%|██████▍   | 369/573 [04:03<02:05,  1.63it/s]
# Epoch 1 in training:  65%|██████▍   | 370/573 [04:03<02:02,  1.66it/s]
# Epoch 1 in training:  65%|██████▍   | 371/573 [04:04<02:03,  1.64it/s]
# Epoch 1 in training:  65%|██████▍   | 372/573 [04:04<01:59,  1.69it/s]
# Epoch 1 in training:  65%|██████▌   | 373/573 [04:05<01:55,  1.72it/s]
# Epoch 1 in training:  65%|██████▌   | 374/573 [04:06<01:53,  1.75it/s]
# Epoch 1 in training:  65%|██████▌   | 375/573 [04:06<01:50,  1.79it/s]
# Epoch 1 in training:  66%|██████▌   | 376/573 [04:07<01:49,  1.81it/s]
# Epoch 1 in training:  66%|██████▌   | 377/573 [04:07<01:50,  1.77it/s]
# Epoch 1 in training:  66%|██████▌   | 378/573 [04:08<01:51,  1.74it/s]
# Epoch 1 in training:  66%|██████▌   | 379/573 [04:08<01:54,  1.70it/s]
# Epoch 1 in training:  66%|██████▋   | 380/573 [04:09<01:51,  1.73it/s]
# Epoch 1 in training:  66%|██████▋   | 381/573 [04:10<01:49,  1.75it/s]
# Epoch 1 in training:  67%|██████▋   | 382/573 [04:10<01:48,  1.75it/s]
# Epoch 1 in training:  67%|██████▋   | 383/573 [04:11<01:50,  1.71it/s]
# Epoch 1 in training:  67%|██████▋   | 384/573 [04:12<02:04,  1.51it/s]
# Epoch 1 in training:  67%|██████▋   | 385/573 [04:12<02:17,  1.37it/s]
# Epoch 1 in training:  67%|██████▋   | 386/573 [04:13<02:24,  1.30it/s]
# Epoch 1 in training:  68%|██████▊   | 387/573 [04:14<02:30,  1.24it/s]
# Epoch 1 in training:  68%|██████▊   | 388/573 [04:15<02:30,  1.23it/s]
# Epoch 1 in training:  68%|██████▊   | 389/573 [04:16<02:18,  1.33it/s]
# Epoch 1 in training:  68%|██████▊   | 390/573 [04:16<02:07,  1.43it/s]
# Epoch 1 in training:  68%|██████▊   | 391/573 [04:17<02:01,  1.49it/s]
# Epoch 1 in training:  68%|██████▊   | 392/573 [04:17<01:55,  1.57it/s]
# Epoch 1 in training:  69%|██████▊   | 393/573 [04:18<01:49,  1.64it/s]
# Epoch 1 in training:  69%|██████▉   | 394/573 [04:18<01:45,  1.69it/s]
# Epoch 1 in training:  69%|██████▉   | 395/573 [04:19<01:41,  1.75it/s]
# Epoch 1 in training:  69%|██████▉   | 396/573 [04:20<01:39,  1.78it/s]
# Epoch 1 in training:  69%|██████▉   | 397/573 [04:20<01:38,  1.80it/s]
# Epoch 1 in training:  69%|██████▉   | 398/573 [04:21<01:37,  1.79it/s]
# Epoch 1 in training:  70%|██████▉   | 399/573 [04:21<01:36,  1.81it/s]
# Epoch 1 in training:  70%|██████▉   | 400/573 [04:22<01:35,  1.82it/s]
# Epoch 1 in training:  70%|██████▉   | 401/573 [04:22<01:35,  1.80it/s]
# Epoch 1 in training:  70%|███████   | 402/573 [04:23<01:35,  1.80it/s]
# Epoch 1 in training:  70%|███████   | 403/573 [04:23<01:32,  1.83it/s]
# Epoch 1 in training:  71%|███████   | 404/573 [04:24<01:31,  1.84it/s]
# Epoch 1 in training:  71%|███████   | 405/573 [04:24<01:32,  1.82it/s]
# Epoch 1 in training:  71%|███████   | 406/573 [04:25<01:31,  1.83it/s]
# Epoch 1 in training:  71%|███████   | 407/573 [04:26<01:40,  1.65it/s]
# Epoch 1 in training:  71%|███████   | 408/573 [04:27<01:51,  1.49it/s]
# Epoch 1 in training:  71%|███████▏  | 409/573 [04:27<01:57,  1.40it/s]
# Epoch 1 in training:  72%|███████▏  | 410/573 [04:28<02:05,  1.30it/s]
# Epoch 1 in training:  72%|███████▏  | 411/573 [04:29<02:11,  1.23it/s]
# Epoch 1 in training:  72%|███████▏  | 412/573 [04:30<02:19,  1.15it/s]
# Epoch 1 in training:  72%|███████▏  | 413/573 [04:31<02:18,  1.16it/s]
# Epoch 1 in training:  72%|███████▏  | 414/573 [04:32<02:16,  1.17it/s]
# Epoch 1 in training:  72%|███████▏  | 415/573 [04:33<02:16,  1.16it/s]
# Epoch 1 in training:  73%|███████▎  | 416/573 [04:34<02:15,  1.16it/s]
# Epoch 1 in training:  73%|███████▎  | 417/573 [04:34<02:09,  1.20it/s]
# Epoch 1 in training:  73%|███████▎  | 418/573 [04:35<01:56,  1.34it/s]
# Epoch 1 in training:  73%|███████▎  | 419/573 [04:36<01:45,  1.46it/s]
# Epoch 1 in training:  73%|███████▎  | 420/573 [04:36<01:36,  1.58it/s]
# Epoch 1 in training:  73%|███████▎  | 421/573 [04:37<01:34,  1.62it/s]
# Epoch 1 in training:  74%|███████▎  | 422/573 [04:37<01:30,  1.67it/s]
# Epoch 1 in training:  74%|███████▍  | 423/573 [04:38<01:26,  1.74it/s]
# Epoch 1 in training:  74%|███████▍  | 424/573 [04:38<01:25,  1.75it/s]
# Epoch 1 in training:  74%|███████▍  | 425/573 [04:39<01:23,  1.77it/s]
# Epoch 1 in training:  74%|███████▍  | 426/573 [04:39<01:23,  1.77it/s]
# Epoch 1 in training:  75%|███████▍  | 427/573 [04:40<01:22,  1.77it/s]
# Epoch 1 in training:  75%|███████▍  | 428/573 [04:40<01:21,  1.79it/s]
# Epoch 1 in training:  75%|███████▍  | 429/573 [04:41<01:30,  1.58it/s]
# Epoch 1 in training:  75%|███████▌  | 430/573 [04:42<01:42,  1.39it/s]
# Epoch 1 in training:  75%|███████▌  | 431/573 [04:43<01:50,  1.29it/s]
# Epoch 1 in training:  75%|███████▌  | 432/573 [04:44<01:54,  1.23it/s]
# Epoch 1 in training:  76%|███████▌  | 433/573 [04:45<01:55,  1.21it/s]
# Epoch 1 in training:  76%|███████▌  | 434/573 [04:46<01:50,  1.26it/s]
# Epoch 1 in training:  76%|███████▌  | 435/573 [04:46<01:39,  1.39it/s]
# Epoch 1 in training:  76%|███████▌  | 436/573 [04:47<01:30,  1.51it/s]
# Epoch 1 in training:  76%|███████▋  | 437/573 [04:47<01:26,  1.57it/s]
# Epoch 1 in training:  76%|███████▋  | 438/573 [04:48<01:23,  1.62it/s]
# Epoch 1 in training:  77%|███████▋  | 439/573 [04:48<01:18,  1.70it/s]
# Epoch 1 in training:  77%|███████▋  | 440/573 [04:49<01:17,  1.71it/s]
# Epoch 1 in training:  77%|███████▋  | 441/573 [04:49<01:16,  1.73it/s]
# Epoch 1 in training:  77%|███████▋  | 442/573 [04:50<01:14,  1.77it/s]
# Epoch 1 in training:  77%|███████▋  | 443/573 [04:51<01:13,  1.77it/s]
# Epoch 1 in training:  77%|███████▋  | 444/573 [04:51<01:14,  1.74it/s]
# Epoch 1 in training:  78%|███████▊  | 445/573 [04:52<01:14,  1.71it/s]
# Epoch 1 in training:  78%|███████▊  | 446/573 [04:52<01:12,  1.75it/s]
# Epoch 1 in training:  78%|███████▊  | 447/573 [04:53<01:11,  1.77it/s]
# Epoch 1 in training:  78%|███████▊  | 448/573 [04:53<01:09,  1.80it/s]
# Epoch 1 in training:  78%|███████▊  | 449/573 [04:54<01:09,  1.79it/s]
# Epoch 1 in training:  79%|███████▊  | 450/573 [04:54<01:08,  1.80it/s]
# Epoch 1 in training:  79%|███████▊  | 451/573 [04:55<01:08,  1.79it/s]
# Epoch 1 in training:  79%|███████▉  | 452/573 [04:56<01:15,  1.60it/s]
# Epoch 1 in training:  79%|███████▉  | 453/573 [04:57<01:21,  1.47it/s]
# Epoch 1 in training:  79%|███████▉  | 454/573 [04:57<01:26,  1.38it/s]
# Epoch 1 in training:  79%|███████▉  | 455/573 [04:58<01:28,  1.33it/s]
# Epoch 1 in training:  80%|███████▉  | 456/573 [04:59<01:29,  1.30it/s]
# Epoch 1 in training:  80%|███████▉  | 457/573 [05:00<01:29,  1.30it/s]
# Epoch 1 in training:  80%|███████▉  | 458/573 [05:00<01:20,  1.43it/s]
# Epoch 1 in training:  80%|████████  | 459/573 [05:01<01:15,  1.52it/s]
# Epoch 1 in training:  80%|████████  | 460/573 [05:02<01:10,  1.59it/s]
# Epoch 1 in training:  80%|████████  | 461/573 [05:02<01:07,  1.65it/s]
# Epoch 1 in training:  81%|████████  | 462/573 [05:03<01:05,  1.69it/s]
# Epoch 1 in training:  81%|████████  | 463/573 [05:03<01:03,  1.73it/s]
# Epoch 1 in training:  81%|████████  | 464/573 [05:04<01:01,  1.76it/s]
# Epoch 1 in training:  81%|████████  | 465/573 [05:04<01:01,  1.76it/s]
# Epoch 1 in training:  81%|████████▏ | 466/573 [05:05<01:00,  1.78it/s]
# Epoch 1 in training:  82%|████████▏ | 467/573 [05:05<00:58,  1.80it/s]
# Epoch 1 in training:  82%|████████▏ | 468/573 [05:06<00:57,  1.82it/s]
# Epoch 1 in training:  82%|████████▏ | 469/573 [05:07<00:58,  1.78it/s]
# Epoch 1 in training:  82%|████████▏ | 470/573 [05:07<00:57,  1.79it/s]
# Epoch 1 in training:  82%|████████▏ | 471/573 [05:08<00:57,  1.77it/s]
# Epoch 1 in training:  82%|████████▏ | 472/573 [05:08<00:57,  1.77it/s]
# Epoch 1 in training:  83%|████████▎ | 473/573 [05:09<00:55,  1.79it/s]
# Epoch 1 in training:  83%|████████▎ | 474/573 [05:09<00:56,  1.74it/s]
# Epoch 1 in training:  83%|████████▎ | 475/573 [05:10<00:58,  1.68it/s]
# Epoch 1 in training:  83%|████████▎ | 476/573 [05:11<01:05,  1.49it/s]
# Epoch 1 in training:  83%|████████▎ | 477/573 [05:12<01:12,  1.33it/s]
# Epoch 1 in training:  83%|████████▎ | 478/573 [05:13<01:16,  1.24it/s]
# Epoch 1 in training:  84%|████████▎ | 479/573 [05:14<01:17,  1.21it/s]
# Epoch 1 in training:  84%|████████▍ | 480/573 [05:14<01:18,  1.19it/s]
# Epoch 1 in training:  84%|████████▍ | 481/573 [05:15<01:10,  1.30it/s]
# Epoch 1 in training:  84%|████████▍ | 482/573 [05:16<01:05,  1.40it/s]
# Epoch 1 in training:  84%|████████▍ | 483/573 [05:16<01:00,  1.48it/s]
# Epoch 1 in training:  84%|████████▍ | 484/573 [05:17<00:57,  1.55it/s]
# Epoch 1 in training:  85%|████████▍ | 485/573 [05:17<00:55,  1.59it/s]
# Epoch 1 in training:  85%|████████▍ | 486/573 [05:18<00:53,  1.62it/s]
# Epoch 1 in training:  85%|████████▍ | 487/573 [05:19<00:52,  1.65it/s]
# Epoch 1 in training:  85%|████████▌ | 488/573 [05:19<00:50,  1.68it/s]
# Epoch 1 in training:  85%|████████▌ | 489/573 [05:20<00:49,  1.70it/s]
# Epoch 1 in training:  86%|████████▌ | 490/573 [05:20<00:48,  1.73it/s]
# Epoch 1 in training:  86%|████████▌ | 491/573 [05:21<00:46,  1.77it/s]
# Epoch 1 in training:  86%|████████▌ | 492/573 [05:21<00:45,  1.77it/s]
# Epoch 1 in training:  86%|████████▌ | 493/573 [05:22<00:44,  1.78it/s]
# Epoch 1 in training:  86%|████████▌ | 494/573 [05:23<00:44,  1.79it/s]
# Epoch 1 in training:  86%|████████▋ | 495/573 [05:23<00:43,  1.78it/s]
# Epoch 1 in training:  87%|████████▋ | 496/573 [05:24<00:44,  1.75it/s]
# Epoch 1 in training:  87%|████████▋ | 497/573 [05:24<00:44,  1.72it/s]
# Epoch 1 in training:  87%|████████▋ | 498/573 [05:25<00:46,  1.60it/s]
# Epoch 1 in training:  87%|████████▋ | 499/573 [05:26<00:50,  1.47it/s]
# Epoch 1 in training:  87%|████████▋ | 500/573 [05:27<00:53,  1.38it/s]
# Epoch 1 in training:  87%|████████▋ | 501/573 [05:27<00:54,  1.32it/s]
# Epoch 1 in training:  88%|████████▊ | 502/573 [05:28<00:56,  1.26it/s]
# Epoch 1 in training:  88%|████████▊ | 503/573 [05:29<00:57,  1.23it/s]
# Epoch 1 in training:  88%|████████▊ | 504/573 [05:30<00:50,  1.37it/s]
# Epoch 1 in training:  88%|████████▊ | 505/573 [05:30<00:46,  1.45it/s]
# Epoch 1 in training:  88%|████████▊ | 506/573 [05:31<00:43,  1.54it/s]
# Epoch 1 in training:  88%|████████▊ | 507/573 [05:31<00:41,  1.60it/s]
# Epoch 1 in training:  89%|████████▊ | 508/573 [05:32<00:40,  1.62it/s]
# Epoch 1 in training:  89%|████████▉ | 509/573 [05:33<00:39,  1.60it/s]
# Epoch 1 in training:  89%|████████▉ | 510/573 [05:33<00:38,  1.63it/s]
# Epoch 1 in training:  89%|████████▉ | 511/573 [05:34<00:37,  1.67it/s]
# Epoch 1 in training:  89%|████████▉ | 512/573 [05:34<00:36,  1.68it/s]
# Epoch 1 in training:  90%|████████▉ | 513/573 [05:35<00:34,  1.72it/s]
# Epoch 1 in training:  90%|████████▉ | 514/573 [05:36<00:34,  1.72it/s]
# Epoch 1 in training:  90%|████████▉ | 515/573 [05:36<00:33,  1.76it/s]
# Epoch 1 in training:  90%|█████████ | 516/573 [05:37<00:32,  1.75it/s]
# Epoch 1 in training:  90%|█████████ | 517/573 [05:37<00:31,  1.76it/s]
# Epoch 1 in training:  90%|█████████ | 518/573 [05:38<00:31,  1.74it/s]
# Epoch 1 in training:  91%|█████████ | 519/573 [05:38<00:31,  1.72it/s]
# Epoch 1 in training:  91%|█████████ | 520/573 [05:39<00:30,  1.72it/s]
# Epoch 1 in training:  91%|█████████ | 521/573 [05:40<00:34,  1.50it/s]
# Epoch 1 in training:  91%|█████████ | 522/573 [05:41<00:37,  1.37it/s]
# Epoch 1 in training:  91%|█████████▏| 523/573 [05:42<00:38,  1.30it/s]
# Epoch 1 in training:  91%|█████████▏| 524/573 [05:43<00:39,  1.25it/s]
# Epoch 1 in training:  92%|█████████▏| 525/573 [05:43<00:40,  1.18it/s]
# Epoch 1 in training:  92%|█████████▏| 526/573 [05:44<00:38,  1.22it/s]
# Epoch 1 in training:  92%|█████████▏| 527/573 [05:45<00:34,  1.34it/s]
# Epoch 1 in training:  92%|█████████▏| 528/573 [05:45<00:31,  1.45it/s]
# Epoch 1 in training:  92%|█████████▏| 529/573 [05:46<00:29,  1.51it/s]
# Epoch 1 in training:  92%|█████████▏| 530/573 [05:47<00:27,  1.58it/s]
# Epoch 1 in training:  93%|█████████▎| 531/573 [05:47<00:25,  1.63it/s]
# Epoch 1 in training:  93%|█████████▎| 532/573 [05:48<00:24,  1.67it/s]
# Epoch 1 in training:  93%|█████████▎| 533/573 [05:48<00:23,  1.70it/s]
# Epoch 1 in training:  93%|█████████▎| 534/573 [05:49<00:22,  1.71it/s]
# Epoch 1 in training:  93%|█████████▎| 535/573 [05:49<00:21,  1.76it/s]
# Epoch 1 in training:  94%|█████████▎| 536/573 [05:50<00:21,  1.72it/s]
# Epoch 1 in training:  94%|█████████▎| 537/573 [05:50<00:20,  1.73it/s]
# Epoch 1 in training:  94%|█████████▍| 538/573 [05:51<00:19,  1.76it/s]
# Epoch 1 in training:  94%|█████████▍| 539/573 [05:52<00:19,  1.75it/s]
# Epoch 1 in training:  94%|█████████▍| 540/573 [05:52<00:20,  1.59it/s]
# Epoch 1 in training:  94%|█████████▍| 541/573 [05:53<00:19,  1.64it/s]
# Epoch 1 in training:  95%|█████████▍| 542/573 [05:54<00:18,  1.68it/s]
# Epoch 1 in training:  95%|█████████▍| 543/573 [05:54<00:17,  1.67it/s]
# Epoch 1 in training:  95%|█████████▍| 544/573 [05:55<00:19,  1.50it/s]
# Epoch 1 in training:  95%|█████████▌| 545/573 [05:56<00:20,  1.39it/s]
# Epoch 1 in training:  95%|█████████▌| 546/573 [05:57<00:20,  1.35it/s]
# Epoch 1 in training:  95%|█████████▌| 547/573 [05:57<00:19,  1.32it/s]
# Epoch 1 in training:  96%|█████████▌| 548/573 [05:58<00:19,  1.30it/s]
# Epoch 1 in training:  96%|█████████▌| 549/573 [05:59<00:17,  1.35it/s]
# Epoch 1 in training:  96%|█████████▌| 550/573 [05:59<00:15,  1.46it/s]
# Epoch 1 in training:  96%|█████████▌| 551/573 [06:00<00:14,  1.55it/s]
# Epoch 1 in training:  96%|█████████▋| 552/573 [06:01<00:13,  1.61it/s]
# Epoch 1 in training:  97%|█████████▋| 553/573 [06:01<00:11,  1.69it/s]
# Epoch 1 in training:  97%|█████████▋| 554/573 [06:02<00:10,  1.75it/s]
# Epoch 1 in training:  97%|█████████▋| 555/573 [06:02<00:10,  1.74it/s]
# Epoch 1 in training:  97%|█████████▋| 556/573 [06:03<00:09,  1.74it/s]
# Epoch 1 in training:  97%|█████████▋| 557/573 [06:03<00:09,  1.75it/s]
# Epoch 1 in training:  97%|█████████▋| 558/573 [06:04<00:08,  1.77it/s]
# Epoch 1 in training:  98%|█████████▊| 559/573 [06:04<00:07,  1.77it/s]
# Epoch 1 in training:  98%|█████████▊| 560/573 [06:05<00:07,  1.78it/s]
# Epoch 1 in training:  98%|█████████▊| 561/573 [06:05<00:06,  1.80it/s]
# Epoch 1 in training:  98%|█████████▊| 562/573 [06:06<00:06,  1.82it/s]
# Epoch 1 in training:  98%|█████████▊| 563/573 [06:07<00:05,  1.81it/s]
# Epoch 1 in training:  98%|█████████▊| 564/573 [06:07<00:04,  1.82it/s]
# Epoch 1 in training:  99%|█████████▊| 565/573 [06:08<00:04,  1.82it/s]
# Epoch 1 in training:  99%|█████████▉| 566/573 [06:08<00:03,  1.83it/s]
# Epoch 1 in training:  99%|█████████▉| 567/573 [06:09<00:03,  1.79it/s]
# Epoch 1 in training:  99%|█████████▉| 568/573 [06:10<00:03,  1.57it/s]
# Epoch 1 in training:  99%|█████████▉| 569/573 [06:11<00:02,  1.42it/s]
# Epoch 1 in training:  99%|█████████▉| 570/573 [06:11<00:02,  1.35it/s]
# Epoch 1 in training: 100%|█████████▉| 571/573 [06:12<00:01,  1.27it/s]
# Epoch 1 in training: 100%|█████████▉| 572/573 [06:13<00:00,  1.23it/s]
# Epoch 1 in training: 100%|██████████| 573/573 [06:13<00:00,  1.51it/s]
# Training:  33%|███▎      | 1/3 [06:13<12:27, 373.93s/it]
# Epoch 1/3 loss: 2.21
# Epoch 2 in training:   0%|          | 0/573 [00:00<?, ?it/s]
# Epoch 2 in training:   0%|          | 1/573 [00:00<05:30,  1.73it/s]
# Epoch 2 in training:   0%|          | 2/573 [00:01<05:05,  1.87it/s]
# Epoch 2 in training:   1%|          | 3/573 [00:01<05:10,  1.83it/s]
# Epoch 2 in training:   1%|          | 4/573 [00:02<05:09,  1.84it/s]
# Epoch 2 in training:   1%|          | 5/573 [00:02<05:15,  1.80it/s]
# Epoch 2 in training:   1%|          | 6/573 [00:03<05:14,  1.80it/s]
# Epoch 2 in training:   1%|          | 7/573 [00:03<05:14,  1.80it/s]
# Epoch 2 in training:   1%|▏         | 8/573 [00:04<05:11,  1.81it/s]
# Epoch 2 in training:   2%|▏         | 9/573 [00:04<05:11,  1.81it/s]
# Epoch 2 in training:   2%|▏         | 10/573 [00:05<05:07,  1.83it/s]
# Epoch 2 in training:   2%|▏         | 11/573 [00:06<05:02,  1.86it/s]
# Epoch 2 in training:   2%|▏         | 12/573 [00:06<05:00,  1.87it/s]
# Epoch 2 in training:   2%|▏         | 13/573 [00:07<05:00,  1.86it/s]
# Epoch 2 in training:   2%|▏         | 14/573 [00:07<04:59,  1.87it/s]
# Epoch 2 in training:   3%|▎         | 15/573 [00:08<04:56,  1.88it/s]
# Epoch 2 in training:   3%|▎         | 16/573 [00:08<05:02,  1.84it/s]
# Epoch 2 in training:   3%|▎         | 17/573 [00:09<04:59,  1.85it/s]
# Epoch 2 in training:   3%|▎         | 18/573 [00:09<05:04,  1.82it/s]
# Epoch 2 in training:   3%|▎         | 19/573 [00:10<05:39,  1.63it/s]
# Epoch 2 in training:   3%|▎         | 20/573 [00:11<06:11,  1.49it/s]
# Epoch 2 in training:   4%|▎         | 21/573 [00:12<06:36,  1.39it/s]
# Epoch 2 in training:   4%|▍         | 22/573 [00:13<06:47,  1.35it/s]
# Epoch 2 in training:   4%|▍         | 23/573 [00:13<06:59,  1.31it/s]
# Epoch 2 in training:   4%|▍         | 24/573 [00:14<07:00,  1.31it/s]
# Epoch 2 in training:   4%|▍         | 25/573 [00:15<06:29,  1.41it/s]
# Epoch 2 in training:   5%|▍         | 26/573 [00:15<05:57,  1.53it/s]
# Epoch 2 in training:   5%|▍         | 27/573 [00:16<05:34,  1.63it/s]
# Epoch 2 in training:   5%|▍         | 28/573 [00:16<05:21,  1.70it/s]
# Epoch 2 in training:   5%|▌         | 29/573 [00:17<05:13,  1.74it/s]
# Epoch 2 in training:   5%|▌         | 30/573 [00:17<05:06,  1.77it/s]
# Epoch 2 in training:   5%|▌         | 31/573 [00:18<04:57,  1.82it/s]
# Epoch 2 in training:   6%|▌         | 32/573 [00:18<04:56,  1.82it/s]
# Epoch 2 in training:   6%|▌         | 33/573 [00:19<04:56,  1.82it/s]
# Epoch 2 in training:   6%|▌         | 34/573 [00:19<04:55,  1.82it/s]
# Epoch 2 in training:   6%|▌         | 35/573 [00:20<05:00,  1.79it/s]
# Epoch 2 in training:   6%|▋         | 36/573 [00:21<05:00,  1.79it/s]
# Epoch 2 in training:   6%|▋         | 37/573 [00:21<04:58,  1.79it/s]
# Epoch 2 in training:   7%|▋         | 38/573 [00:22<05:01,  1.78it/s]
# Epoch 2 in training:   7%|▋         | 39/573 [00:22<05:02,  1.77it/s]
# Epoch 2 in training:   7%|▋         | 40/573 [00:23<04:59,  1.78it/s]
# Epoch 2 in training:   7%|▋         | 41/573 [00:23<04:52,  1.82it/s]
# Epoch 2 in training:   7%|▋         | 42/573 [00:24<04:54,  1.80it/s]
# Epoch 2 in training:   8%|▊         | 43/573 [00:25<05:34,  1.58it/s]
# Epoch 2 in training:   8%|▊         | 44/573 [00:26<06:11,  1.43it/s]
# Epoch 2 in training:   8%|▊         | 45/573 [00:26<06:28,  1.36it/s]
# Epoch 2 in training:   8%|▊         | 46/573 [00:27<06:39,  1.32it/s]
# Epoch 2 in training:   8%|▊         | 47/573 [00:28<06:53,  1.27it/s]
# Epoch 2 in training:   8%|▊         | 48/573 [00:29<06:49,  1.28it/s]
# Epoch 2 in training:   9%|▊         | 49/573 [00:29<06:22,  1.37it/s]
# Epoch 2 in training:   9%|▊         | 50/573 [00:30<05:52,  1.48it/s]
# Epoch 2 in training:   9%|▉         | 51/573 [00:31<05:34,  1.56it/s]
# Epoch 2 in training:   9%|▉         | 52/573 [00:31<05:19,  1.63it/s]
# Epoch 2 in training:   9%|▉         | 53/573 [00:32<05:07,  1.69it/s]
# Epoch 2 in training:   9%|▉         | 54/573 [00:32<05:05,  1.70it/s]
# Epoch 2 in training:  10%|▉         | 55/573 [00:33<04:58,  1.74it/s]
# Epoch 2 in training:  10%|▉         | 56/573 [00:33<04:52,  1.77it/s]
# Epoch 2 in training:  10%|▉         | 57/573 [00:34<04:58,  1.73it/s]
# Epoch 2 in training:  10%|█         | 58/573 [00:35<04:56,  1.74it/s]
# Epoch 2 in training:  10%|█         | 59/573 [00:35<04:54,  1.74it/s]
# Epoch 2 in training:  10%|█         | 60/573 [00:36<04:56,  1.73it/s]
# Epoch 2 in training:  11%|█         | 61/573 [00:36<05:00,  1.71it/s]
# Epoch 2 in training:  11%|█         | 62/573 [00:37<04:54,  1.73it/s]
# Epoch 2 in training:  11%|█         | 63/573 [00:37<04:54,  1.73it/s]
# Epoch 2 in training:  11%|█         | 64/573 [00:38<04:45,  1.78it/s]
# Epoch 2 in training:  11%|█▏        | 65/573 [00:39<04:46,  1.77it/s]
# Epoch 2 in training:  12%|█▏        | 66/573 [00:39<05:22,  1.57it/s]
# Epoch 2 in training:  12%|█▏        | 67/573 [00:40<05:51,  1.44it/s]
# Epoch 2 in training:  12%|█▏        | 68/573 [00:41<06:10,  1.36it/s]
# Epoch 2 in training:  12%|█▏        | 69/573 [00:42<06:30,  1.29it/s]
# Epoch 2 in training:  12%|█▏        | 70/573 [00:43<06:38,  1.26it/s]
# Epoch 2 in training:  12%|█▏        | 71/573 [00:43<06:25,  1.30it/s]
# Epoch 2 in training:  13%|█▎        | 72/573 [00:44<05:47,  1.44it/s]
# Epoch 2 in training:  13%|█▎        | 73/573 [00:44<05:23,  1.55it/s]
# Epoch 2 in training:  13%|█▎        | 74/573 [00:45<05:04,  1.64it/s]
# Epoch 2 in training:  13%|█▎        | 75/573 [00:46<04:53,  1.70it/s]
# Epoch 2 in training:  13%|█▎        | 76/573 [00:46<04:47,  1.73it/s]
# Epoch 2 in training:  13%|█▎        | 77/573 [00:47<04:44,  1.74it/s]
# Epoch 2 in training:  14%|█▎        | 78/573 [00:47<04:41,  1.76it/s]
# Epoch 2 in training:  14%|█▍        | 79/573 [00:48<04:35,  1.79it/s]
# Epoch 2 in training:  14%|█▍        | 80/573 [00:48<04:36,  1.78it/s]
# Epoch 2 in training:  14%|█▍        | 81/573 [00:49<04:37,  1.77it/s]
# Epoch 2 in training:  14%|█▍        | 82/573 [00:49<04:35,  1.78it/s]
# Epoch 2 in training:  14%|█▍        | 83/573 [00:50<04:36,  1.77it/s]
# Epoch 2 in training:  15%|█▍        | 84/573 [00:51<04:34,  1.78it/s]
# Epoch 2 in training:  15%|█▍        | 85/573 [00:51<04:27,  1.82it/s]
# Epoch 2 in training:  15%|█▌        | 86/573 [00:52<04:26,  1.83it/s]
# Epoch 2 in training:  15%|█▌        | 87/573 [00:52<04:21,  1.86it/s]
# Epoch 2 in training:  15%|█▌        | 88/573 [00:53<04:29,  1.80it/s]
# Epoch 2 in training:  16%|█▌        | 89/573 [00:53<04:34,  1.76it/s]
# Epoch 2 in training:  16%|█▌        | 90/573 [00:54<05:06,  1.57it/s]
# Epoch 2 in training:  16%|█▌        | 91/573 [00:55<05:31,  1.46it/s]
# Epoch 2 in training:  16%|█▌        | 92/573 [00:56<05:55,  1.35it/s]
# Epoch 2 in training:  16%|█▌        | 93/573 [00:57<06:04,  1.32it/s]
# Epoch 2 in training:  16%|█▋        | 94/573 [00:57<06:17,  1.27it/s]
# Epoch 2 in training:  17%|█▋        | 95/573 [00:58<06:12,  1.28it/s]
# Epoch 2 in training:  17%|█▋        | 96/573 [00:59<05:41,  1.40it/s]
# Epoch 2 in training:  17%|█▋        | 97/573 [00:59<05:20,  1.48it/s]
# Epoch 2 in training:  17%|█▋        | 98/573 [01:00<05:03,  1.56it/s]
# Epoch 2 in training:  17%|█▋        | 99/573 [01:00<04:52,  1.62it/s]
# Epoch 2 in training:  17%|█▋        | 100/573 [01:01<04:43,  1.67it/s]
# Epoch 2 in training:  18%|█▊        | 101/573 [01:02<04:35,  1.71it/s]
# Epoch 2 in training:  18%|█▊        | 102/573 [01:02<04:32,  1.73it/s]
# ...
# Epoch 3 in training:  52%|█████▏    | 246/469 [02:40<02:07,  1.75it/s]
# Epoch 3 in training:  53%|█████▎    | 247/469 [02:40<02:06,  1.75it/s]
# Epoch 3 in training:  53%|█████▎    | 248/469 [02:41<02:05,  1.76it/s]
# Epoch 3 in training:  53%|█████▎    | 249/469 [02:42<02:05,  1.76it/s]
# Epoch 3 in training:  53%|█████▎    | 250/469 [02:42<02:04,  1.77it/s]
# Epoch 3 in training:  54%|█████▎    | 251/469 [02:43<02:21,  1.54it/s]
# Epoch 3 in training:  54%|█████▎    | 252/469 [02:44<02:34,  1.40it/s]
# Epoch 3 in training:  54%|█████▍    | 253/469 [02:45<02:41,  1.34it/s]
# Epoch 3 in training:  54%|█████▍    | 254/469 [02:45<02:46,  1.29it/s]
# Epoch 3 in training:  54%|█████▍    | 255/469 [02:46<02:50,  1.26it/s]
# Epoch 3 in training:  55%|█████▍    | 256/469 [02:47<02:44,  1.30it/s]
# Epoch 3 in training:  55%|█████▍    | 257/469 [02:48<02:30,  1.40it/s]
# Epoch 3 in training:  55%|█████▌    | 258/469 [02:48<02:20,  1.51it/s]
# Epoch 3 in training:  55%|█████▌    | 259/469 [02:49<02:14,  1.56it/s]
# Epoch 3 in training:  55%|█████▌    | 260/469 [02:49<02:08,  1.63it/s]
# Epoch 3 in training:  56%|█████▌    | 261/469 [02:50<02:04,  1.67it/s]
# Epoch 3 in training:  56%|█████▌    | 262/469 [02:50<02:02,  1.70it/s]
# Epoch 3 in training:  56%|█████▌    | 263/469 [02:51<02:00,  1.71it/s]
# Epoch 3 in training:  56%|█████▋    | 264/469 [02:52<01:58,  1.72it/s]
# Epoch 3 in training:  57%|█████▋    | 265/469 [02:52<02:01,  1.68it/s]
# Epoch 3 in training:  57%|█████▋    | 266/469 [02:53<02:02,  1.66it/s]
# Epoch 3 in training:  57%|█████▋    | 267/469 [02:53<02:00,  1.68it/s]
# Epoch 3 in training:  57%|█████▋    | 268/469 [02:54<02:00,  1.67it/s]
# Epoch 3 in training:  57%|█████▋    | 269/469 [02:55<02:00,  1.66it/s]
# Epoch 3 in training:  58%|█████▊    | 270/469 [02:55<02:05,  1.59it/s]
# Epoch 3 in training:  58%|█████▊    | 271/469 [02:56<02:08,  1.54it/s]
# Epoch 3 in training:  58%|█████▊    | 272/469 [02:57<02:02,  1.60it/s]
# Epoch 3 in training:  58%|█████▊    | 273/469 [02:57<02:10,  1.50it/s]
# Epoch 3 in training:  58%|█████▊    | 274/469 [02:58<02:21,  1.38it/s]
# Epoch 3 in training:  59%|█████▊    | 275/469 [02:59<02:27,  1.32it/s]
# Epoch 3 in training:  59%|█████▉    | 276/469 [03:00<02:30,  1.29it/s]
# Epoch 3 in training:  59%|█████▉    | 277/469 [03:01<02:32,  1.26it/s]
# Epoch 3 in training:  59%|█████▉    | 278/469 [03:01<02:31,  1.26it/s]
# Epoch 3 in training:  59%|█████▉    | 279/469 [03:02<02:19,  1.36it/s]
# Epoch 3 in training:  60%|█████▉    | 280/469 [03:03<02:08,  1.47it/s]
# Epoch 3 in training:  60%|█████▉    | 281/469 [03:03<02:01,  1.55it/s]
# Epoch 3 in training:  60%|██████    | 282/469 [03:04<02:00,  1.56it/s]
# Epoch 3 in training:  60%|██████    | 283/469 [03:04<01:57,  1.59it/s]
# Epoch 3 in training:  61%|██████    | 284/469 [03:05<01:52,  1.64it/s]
# Epoch 3 in training:  61%|██████    | 285/469 [03:06<01:50,  1.67it/s]
# Epoch 3 in training:  61%|██████    | 286/469 [03:06<01:48,  1.69it/s]
# Epoch 3 in training:  61%|██████    | 287/469 [03:07<01:44,  1.74it/s]
# Epoch 3 in training:  61%|██████▏   | 288/469 [03:07<01:44,  1.73it/s]
# Epoch 3 in training:  62%|██████▏   | 289/469 [03:08<01:42,  1.76it/s]
# Epoch 3 in training:  62%|██████▏   | 290/469 [03:08<01:42,  1.75it/s]
# Epoch 3 in training:  62%|██████▏   | 291/469 [03:09<01:41,  1.76it/s]
# Epoch 3 in training:  62%|██████▏   | 292/469 [03:09<01:39,  1.77it/s]
# Epoch 3 in training:  62%|██████▏   | 293/469 [03:10<01:39,  1.78it/s]
# Epoch 3 in training:  63%|██████▎   | 294/469 [03:11<01:40,  1.74it/s]
# Epoch 3 in training:  63%|██████▎   | 295/469 [03:11<01:41,  1.71it/s]
# Epoch 3 in training:  63%|██████▎   | 296/469 [03:12<01:53,  1.53it/s]
# Epoch 3 in training:  63%|██████▎   | 297/469 [03:13<02:01,  1.41it/s]
# Epoch 3 in training:  64%|██████▎   | 298/469 [03:14<02:07,  1.35it/s]
# Epoch 3 in training:  64%|██████▍   | 299/469 [03:15<02:10,  1.30it/s]
# Epoch 3 in training:  64%|██████▍   | 300/469 [03:15<02:13,  1.27it/s]
# Epoch 3 in training:  64%|██████▍   | 301/469 [03:16<02:09,  1.30it/s]
# Epoch 3 in training:  64%|██████▍   | 302/469 [03:17<01:58,  1.41it/s]
# Epoch 3 in training:  65%|██████▍   | 303/469 [03:17<01:49,  1.52it/s]
# Epoch 3 in training:  65%|██████▍   | 304/469 [03:18<01:44,  1.59it/s]
# Epoch 3 in training:  65%|██████▌   | 305/469 [03:18<01:39,  1.65it/s]
# Epoch 3 in training:  65%|██████▌   | 306/469 [03:19<01:37,  1.67it/s]
# Epoch 3 in training:  65%|██████▌   | 307/469 [03:19<01:34,  1.71it/s]
# Epoch 3 in training:  66%|██████▌   | 308/469 [03:20<01:33,  1.73it/s]
# Epoch 3 in training:  66%|██████▌   | 309/469 [03:21<01:30,  1.76it/s]
# Epoch 3 in training:  66%|██████▌   | 310/469 [03:21<01:29,  1.77it/s]
# Epoch 3 in training:  66%|██████▋   | 311/469 [03:22<01:28,  1.79it/s]
# Epoch 3 in training:  67%|██████▋   | 312/469 [03:22<01:26,  1.81it/s]
# Epoch 3 in training:  67%|██████▋   | 313/469 [03:23<01:27,  1.79it/s]
# Epoch 3 in training:  67%|██████▋   | 314/469 [03:23<01:27,  1.76it/s]
# Epoch 3 in training:  67%|██████▋   | 315/469 [03:24<01:38,  1.56it/s]
# Epoch 3 in training:  67%|██████▋   | 316/469 [03:25<01:47,  1.42it/s]
# Epoch 3 in training:  68%|██████▊   | 317/469 [03:26<01:53,  1.34it/s]
# Epoch 3 in training:  68%|██████▊   | 318/469 [03:27<02:02,  1.23it/s]
# Epoch 3 in training:  68%|██████▊   | 319/469 [03:28<02:02,  1.22it/s]
# Epoch 3 in training:  68%|██████▊   | 320/469 [03:29<02:09,  1.15it/s]
# Epoch 3 in training:  68%|██████▊   | 321/469 [03:30<02:08,  1.15it/s]
# Epoch 3 in training:  69%|██████▊   | 322/469 [03:30<02:05,  1.17it/s]
# Epoch 3 in training:  69%|██████▉   | 323/469 [03:31<02:03,  1.18it/s]
# Epoch 3 in training:  69%|██████▉   | 324/469 [03:32<02:01,  1.19it/s]
# Epoch 3 in training:  69%|██████▉   | 325/469 [03:33<01:50,  1.30it/s]
# Epoch 3 in training:  70%|██████▉   | 326/469 [03:33<01:48,  1.31it/s]
# Epoch 3 in training:  70%|██████▉   | 327/469 [03:34<01:39,  1.43it/s]
# Epoch 3 in training:  70%|██████▉   | 328/469 [03:34<01:32,  1.53it/s]
# Epoch 3 in training:  70%|███████   | 329/469 [03:35<01:27,  1.60it/s]
# Epoch 3 in training:  70%|███████   | 330/469 [03:36<01:24,  1.64it/s]
# Epoch 3 in training:  71%|███████   | 331/469 [03:36<01:21,  1.69it/s]
# Epoch 3 in training:  71%|███████   | 332/469 [03:37<01:19,  1.72it/s]
# Epoch 3 in training:  71%|███████   | 333/469 [03:37<01:21,  1.68it/s]
# Epoch 3 in training:  71%|███████   | 334/469 [03:38<01:21,  1.67it/s]
# Epoch 3 in training:  71%|███████▏  | 335/469 [03:38<01:19,  1.69it/s]
# Epoch 3 in training:  72%|███████▏  | 336/469 [03:39<01:17,  1.71it/s]
# Epoch 3 in training:  72%|███████▏  | 337/469 [03:40<01:17,  1.69it/s]
# Epoch 3 in training:  72%|███████▏  | 338/469 [03:40<01:15,  1.73it/s]
# Epoch 3 in training:  72%|███████▏  | 339/469 [03:41<01:14,  1.75it/s]
# Epoch 3 in training:  72%|███████▏  | 340/469 [03:41<01:14,  1.74it/s]
# Epoch 3 in training:  73%|███████▎  | 341/469 [03:42<01:14,  1.72it/s]
# Epoch 3 in training:  73%|███████▎  | 342/469 [03:43<01:22,  1.54it/s]
# Epoch 3 in training:  73%|███████▎  | 343/469 [03:44<01:28,  1.42it/s]
# Epoch 3 in training:  73%|███████▎  | 344/469 [03:44<01:32,  1.35it/s]
# Epoch 3 in training:  74%|███████▎  | 345/469 [03:45<01:34,  1.31it/s]
# Epoch 3 in training:  74%|███████▍  | 346/469 [03:46<01:35,  1.29it/s]
# Epoch 3 in training:  74%|███████▍  | 347/469 [03:47<01:37,  1.26it/s]
# Epoch 3 in training:  74%|███████▍  | 348/469 [03:47<01:27,  1.38it/s]
# Epoch 3 in training:  74%|███████▍  | 349/469 [03:48<01:20,  1.49it/s]
# Epoch 3 in training:  75%|███████▍  | 350/469 [03:49<01:15,  1.57it/s]
# Epoch 3 in training:  75%|███████▍  | 351/469 [03:49<01:13,  1.61it/s]
# Epoch 3 in training:  75%|███████▌  | 352/469 [03:50<01:10,  1.65it/s]
# Epoch 3 in training:  75%|███████▌  | 353/469 [03:50<01:08,  1.70it/s]
# Epoch 3 in training:  75%|███████▌  | 354/469 [03:51<01:07,  1.71it/s]
# Epoch 3 in training:  76%|███████▌  | 355/469 [03:51<01:05,  1.73it/s]
# Epoch 3 in training:  76%|███████▌  | 356/469 [03:52<01:04,  1.75it/s]
# Epoch 3 in training:  76%|███████▌  | 357/469 [03:52<01:03,  1.77it/s]
# Epoch 3 in training:  76%|███████▋  | 358/469 [03:53<01:02,  1.76it/s]
# Epoch 3 in training:  77%|███████▋  | 359/469 [03:54<01:01,  1.79it/s]
# Epoch 3 in training:  77%|███████▋  | 360/469 [03:54<01:01,  1.78it/s]
# Epoch 3 in training:  77%|███████▋  | 361/469 [03:55<01:00,  1.78it/s]
# Epoch 3 in training:  77%|███████▋  | 362/469 [03:55<01:00,  1.77it/s]
# Epoch 3 in training:  77%|███████▋  | 363/469 [03:56<01:01,  1.73it/s]
# Epoch 3 in training:  78%|███████▊  | 364/469 [03:57<01:02,  1.68it/s]
# Epoch 3 in training:  78%|███████▊  | 365/469 [03:57<01:07,  1.55it/s]
# Epoch 3 in training:  78%|███████▊  | 366/469 [03:58<01:12,  1.42it/s]
# Epoch 3 in training:  78%|███████▊  | 367/469 [03:59<01:15,  1.35it/s]
# Epoch 3 in training:  78%|███████▊  | 368/469 [04:00<01:17,  1.30it/s]
# Epoch 3 in training:  79%|███████▊  | 369/469 [04:01<01:18,  1.28it/s]
# Epoch 3 in training:  79%|███████▉  | 370/469 [04:01<01:19,  1.24it/s]
# Epoch 3 in training:  79%|███████▉  | 371/469 [04:02<01:12,  1.35it/s]
# Epoch 3 in training:  79%|███████▉  | 372/469 [04:03<01:07,  1.43it/s]
# Epoch 3 in training:  80%|███████▉  | 373/469 [04:03<01:04,  1.49it/s]
# Epoch 3 in training:  80%|███████▉  | 374/469 [04:04<01:01,  1.55it/s]
# Epoch 3 in training:  80%|███████▉  | 375/469 [04:04<00:58,  1.61it/s]
# Epoch 3 in training:  80%|████████  | 376/469 [04:05<00:56,  1.65it/s]
# Epoch 3 in training:  80%|████████  | 377/469 [04:06<00:54,  1.68it/s]
# Epoch 3 in training:  81%|████████  | 378/469 [04:06<00:52,  1.72it/s]
# Epoch 3 in training:  81%|████████  | 379/469 [04:07<00:51,  1.73it/s]
# Epoch 3 in training:  81%|████████  | 380/469 [04:07<00:51,  1.72it/s]
# Epoch 3 in training:  81%|████████  | 381/469 [04:08<00:51,  1.72it/s]
# Epoch 3 in training:  81%|████████▏ | 382/469 [04:08<00:49,  1.75it/s]
# Epoch 3 in training:  82%|████████▏ | 383/469 [04:09<00:49,  1.72it/s]
# Epoch 3 in training:  82%|████████▏ | 384/469 [04:10<00:50,  1.67it/s]
# Epoch 3 in training:  82%|████████▏ | 385/469 [04:10<00:49,  1.70it/s]
# Epoch 3 in training:  82%|████████▏ | 386/469 [04:11<00:48,  1.72it/s]
# Epoch 3 in training:  83%|████████▎ | 387/469 [04:11<00:47,  1.74it/s]
# Epoch 3 in training:  83%|████████▎ | 388/469 [04:12<00:50,  1.60it/s]
# Epoch 3 in training:  83%|████████▎ | 389/469 [04:13<00:54,  1.46it/s]
# Epoch 3 in training:  83%|████████▎ | 390/469 [04:14<00:57,  1.37it/s]
# Epoch 3 in training:  83%|████████▎ | 391/469 [04:15<00:59,  1.31it/s]
# Epoch 3 in training:  84%|████████▎ | 392/469 [04:15<00:59,  1.29it/s]
# Epoch 3 in training:  84%|████████▍ | 393/469 [04:16<00:59,  1.27it/s]
# Epoch 3 in training:  84%|████████▍ | 394/469 [04:17<00:53,  1.40it/s]
# Epoch 3 in training:  84%|████████▍ | 395/469 [04:17<00:49,  1.51it/s]
# Epoch 3 in training:  84%|████████▍ | 396/469 [04:18<00:46,  1.57it/s]
# Epoch 3 in training:  85%|████████▍ | 397/469 [04:18<00:43,  1.64it/s]
# Epoch 3 in training:  85%|████████▍ | 398/469 [04:19<00:42,  1.65it/s]
# Epoch 3 in training:  85%|████████▌ | 399/469 [04:20<00:41,  1.67it/s]
# Epoch 3 in training:  85%|████████▌ | 400/469 [04:20<00:40,  1.69it/s]
# Epoch 3 in training:  86%|████████▌ | 401/469 [04:21<00:40,  1.70it/s]
# Epoch 3 in training:  86%|████████▌ | 402/469 [04:21<00:38,  1.73it/s]
# Epoch 3 in training:  86%|████████▌ | 403/469 [04:22<00:38,  1.71it/s]
# Epoch 3 in training:  86%|████████▌ | 404/469 [04:22<00:37,  1.72it/s]
# Epoch 3 in training:  86%|████████▋ | 405/469 [04:23<00:37,  1.72it/s]
# Epoch 3 in training:  87%|████████▋ | 406/469 [04:24<00:36,  1.71it/s]
# Epoch 3 in training:  87%|████████▋ | 407/469 [04:24<00:36,  1.70it/s]
# Epoch 3 in training:  87%|████████▋ | 408/469 [04:25<00:36,  1.67it/s]
# Epoch 3 in training:  87%|████████▋ | 409/469 [04:25<00:35,  1.67it/s]
# Epoch 3 in training:  87%|████████▋ | 410/469 [04:26<00:35,  1.67it/s]
# Epoch 3 in training:  88%|████████▊ | 411/469 [04:27<00:39,  1.47it/s]
# Epoch 3 in training:  88%|████████▊ | 412/469 [04:28<00:42,  1.35it/s]
# Epoch 3 in training:  88%|████████▊ | 413/469 [04:29<00:43,  1.28it/s]
# Epoch 3 in training:  88%|████████▊ | 414/469 [04:30<00:44,  1.23it/s]
# Epoch 3 in training:  88%|████████▊ | 415/469 [04:30<00:44,  1.20it/s]
# Epoch 3 in training:  89%|████████▊ | 416/469 [04:31<00:41,  1.28it/s]
# Epoch 3 in training:  89%|████████▉ | 417/469 [04:32<00:38,  1.36it/s]
# Epoch 3 in training:  89%|████████▉ | 418/469 [04:32<00:35,  1.44it/s]
# Epoch 3 in training:  89%|████████▉ | 419/469 [04:33<00:33,  1.51it/s]
# Epoch 3 in training:  90%|████████▉ | 420/469 [04:34<00:31,  1.56it/s]
# Epoch 3 in training:  90%|████████▉ | 421/469 [04:34<00:30,  1.58it/s]
# Epoch 3 in training:  90%|████████▉ | 422/469 [04:35<00:29,  1.61it/s]
# Epoch 3 in training:  90%|█████████ | 423/469 [04:35<00:28,  1.64it/s]
# Epoch 3 in training:  90%|█████████ | 424/469 [04:36<00:27,  1.66it/s]
# Epoch 3 in training:  91%|█████████ | 425/469 [04:36<00:26,  1.69it/s]
# Epoch 3 in training:  91%|█████████ | 426/469 [04:37<00:25,  1.69it/s]
# Epoch 3 in training:  91%|█████████ | 427/469 [04:38<00:24,  1.70it/s]
# Epoch 3 in training:  91%|█████████▏| 428/469 [04:38<00:24,  1.70it/s]
# Epoch 3 in training:  91%|█████████▏| 429/469 [04:39<00:23,  1.71it/s]
# Epoch 3 in training:  92%|█████████▏| 430/469 [04:39<00:23,  1.69it/s]
# Epoch 3 in training:  92%|█████████▏| 431/469 [04:40<00:22,  1.68it/s]
# Epoch 3 in training:  92%|█████████▏| 432/469 [04:41<00:21,  1.68it/s]
# Epoch 3 in training:  92%|█████████▏| 433/469 [04:41<00:24,  1.50it/s]
# Epoch 3 in training:  93%|█████████▎| 434/469 [04:42<00:25,  1.37it/s]
# Epoch 3 in training:  93%|█████████▎| 435/469 [04:43<00:26,  1.28it/s]
# Epoch 3 in training:  93%|█████████▎| 436/469 [04:44<00:26,  1.24it/s]
# Epoch 3 in training:  93%|█████████▎| 437/469 [04:45<00:26,  1.20it/s]
# Epoch 3 in training:  93%|█████████▎| 438/469 [04:46<00:24,  1.28it/s]
# Epoch 3 in training:  94%|█████████▎| 439/469 [04:46<00:21,  1.37it/s]
# Epoch 3 in training:  94%|█████████▍| 440/469 [04:47<00:19,  1.45it/s]
# Epoch 3 in training:  94%|█████████▍| 441/469 [04:48<00:19,  1.43it/s]
# Epoch 3 in training:  94%|█████████▍| 442/469 [04:48<00:17,  1.51it/s]
# Epoch 3 in training:  94%|█████████▍| 443/469 [04:49<00:16,  1.56it/s]
# Epoch 3 in training:  95%|█████████▍| 444/469 [04:49<00:15,  1.62it/s]
# Epoch 3 in training:  95%|█████████▍| 445/469 [04:50<00:14,  1.63it/s]
# Epoch 3 in training:  95%|█████████▌| 446/469 [04:50<00:14,  1.64it/s]
# Epoch 3 in training:  95%|█████████▌| 447/469 [04:51<00:13,  1.67it/s]
# Epoch 3 in training:  96%|█████████▌| 448/469 [04:52<00:12,  1.67it/s]
# Epoch 3 in training:  96%|█████████▌| 449/469 [04:52<00:11,  1.68it/s]
# Epoch 3 in training:  96%|█████████▌| 450/469 [04:53<00:11,  1.69it/s]
# Epoch 3 in training:  96%|█████████▌| 451/469 [04:53<00:10,  1.70it/s]
# Epoch 3 in training:  96%|█████████▋| 452/469 [04:54<00:10,  1.68it/s]
# Epoch 3 in training:  97%|█████████▋| 453/469 [04:55<00:09,  1.70it/s]
# Epoch 3 in training:  97%|█████████▋| 454/469 [04:55<00:09,  1.62it/s]
# Epoch 3 in training:  97%|█████████▋| 455/469 [04:56<00:09,  1.43it/s]
# Epoch 3 in training:  97%|█████████▋| 456/469 [04:57<00:09,  1.35it/s]
# Epoch 3 in training:  97%|█████████▋| 457/469 [04:58<00:09,  1.30it/s]
# Epoch 3 in training:  98%|█████████▊| 458/469 [04:59<00:08,  1.26it/s]
# Epoch 3 in training:  98%|█████████▊| 459/469 [05:00<00:08,  1.22it/s]
# Epoch 3 in training:  98%|█████████▊| 460/469 [05:00<00:06,  1.29it/s]
# Epoch 3 in training:  98%|█████████▊| 461/469 [05:01<00:05,  1.40it/s]
# Epoch 3 in training:  99%|█████████▊| 462/469 [05:01<00:04,  1.49it/s]
# Epoch 3 in training:  99%|█████████▊| 463/469 [05:02<00:03,  1.54it/s]
# Epoch 3 in training:  99%|█████████▉| 464/469 [05:03<00:03,  1.60it/s]
# Epoch 3 in training:  99%|█████████▉| 465/469 [05:03<00:02,  1.63it/s]
# Epoch 3 in training:  99%|█████████▉| 466/469 [05:04<00:01,  1.68it/s]
# Epoch 3 in training: 100%|█████████▉| 467/469 [05:04<00:01,  1.70it/s]
# Epoch 3 in training: 100%|█████████▉| 468/469 [05:05<00:00,  1.73it/s]
# Epoch 3 in training: 100%|██████████| 469/469 [05:05<00:00,  1.85it/s]
# Training: 100%|██████████| 3/3 [15:23<00:00, 307.69s/it]
# Epoch 3/3 loss: 1.64

# %%
mat_test = scipy.io.loadmat('/content/drive/MyDrive/test_32x32.mat')

Data_test = []
Label_test = []

for i in range(mat_test['X'].T.shape[0]):
    a = mat['X'].T[i]
    a = np.mean(a, axis = 0)
    a = a.reshape((1, 32, 32)) 


    Data_test.append(a)
    Label_test.append(mat_test['y'][i])

Data_test = np.asarray(Data_test)
Label_test = np.asarray(Label_test)

Label_test[Label_test == 10] = 1

print(max(Label_test))

test_x = torch.Tensor(Data_test)
test_y = torch.Tensor(Label_test)

print(train_x[55].shape)
SVHN_dataset_test = utils.data.TensorDataset(test_x, test_y)

test_loader = DataLoader(SVHN_dataset_test, shuffle=False, batch_size=128)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9b88e7fcc2fc> in <cell line: 1>()
# ----> 1 mat_test = scipy.io.loadmat('/content/drive/MyDrive/test_32x32.mat')
#       2
#       3 Data_test = []
#       4 Label_test = []
#       5
#
# NameError: name 'scipy' is not defined

# %%
with torch.no_grad():
    correct, total = 0, 0
    test_loss = 0.0
    for batch in tqdm(test_loader, desc="Testing"):
        x, y = batch
        x, y = x, y
        y = torch.reshape(y, (-1,))
        y = y.type(torch.LongTensor)
        y_hat = model(x)
        loss = criterion(y_hat, y)
        test_loss += loss.detach().cpu().item() / len(test_loader)

        correct += torch.sum(torch.argmax(y_hat, dim=1) == y).detach().cpu().item()
        total += len(x)
    print(f"Test loss: {test_loss:.2f}")
    print(f"Test accuracy: {correct / total * 100:.2f}%")
# Out:
# Testing: 100%|██████████| 204/204 [01:07<00:00,  3.02it/s]
# Test loss: 2.35
# Test accuracy: 11.07%

# %%
class USPS_Dataset(torch.utils.data.Dataset):
    def __init__(self, path, key):
        self.file_path = path
        self.dataset = None
        with h5py.File(self.file_path, 'r') as file:
            key_set = file.get(key)
            X = key_set.get("data")[:]
            y = key_set.get("target")[:]
        X = X.reshape(X.shape[0], 1, int(np.sqrt(X.shape[1])), int(np.sqrt(X.shape[1])))
        y = torch.from_numpy(y)
        y = y.type(torch.LongTensor)
        self.dataset = [(image, target) for image, target in zip(X, y)]
        self.dataset_len = len(self.dataset)


    def __getitem__(self, index):
        X, y = self.dataset[index]
        tmp = Image.fromarray(X[0])
        tmp = tmp.resize((32, 32), resample=Image.Resampling.BICUBIC)
        tmp = np.array(tmp, dtype=np.uint8)
        tmp[tmp==0] = 1/255
        return (torch.from_numpy(tmp.reshape(1, tmp.shape[0], tmp.shape[1])), y)


    def __len__(self):
        return self.dataset_len

# %%
test_set = USPS_Dataset("/content/drive/MyDrive/usps.h5", "train")
test_loader = DataLoader(test_set, shuffle=False, batch_size=128)

# %%
with torch.no_grad():
    correct, total = 0, 0
    test_loss = 0.0
    for batch in tqdm(test_loader, desc="Testing"):
        x, y = batch
        x, y = x, y
        y_hat = model(x)
        loss = criterion(y_hat, y)
        test_loss += loss.detach().cpu().item() / len(test_loader)

        correct += torch.sum(torch.argmax(y_hat, dim=1) == y).detach().cpu().item()
        total += len(x)
    print(f"Test loss: {test_loss:.2f}")
    print(f"Test accuracy: {correct / total * 100:.2f}%")
# Out:
# Testing: 100%|██████████| 57/57 [00:20<00:00,  2.85it/s]
# Test loss: 2.21
# Test accuracy: 24.08%

# %%
import torchvision
import tempfile

dataset = torchvision.datasets.MNIST(root=tempfile.gettempdir(), download=True,
    train=False,transform=torchvision.transforms.Compose([
        torchvision.transforms.Resize(32), torchvision.transforms.ToTensor()]
    ),
)
test_loader = DataLoader(dataset, shuffle=False, batch_size=128)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /tmp/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 92028694.41it/s]
# Extracting /tmp/MNIST/raw/train-images-idx3-ubyte.gz to /tmp/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /tmp/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 33024998.32it/s]
# Extracting /tmp/MNIST/raw/train-labels-idx1-ubyte.gz to /tmp/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /tmp/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 25991383.91it/s]
# Extracting /tmp/MNIST/raw/t10k-images-idx3-ubyte.gz to /tmp/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /tmp/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 14080213.43it/s]
# Extracting /tmp/MNIST/raw/t10k-labels-idx1-ubyte.gz to /tmp/MNIST/raw

# %%
with torch.no_grad():
    correct, total = 0, 0
    test_loss = 0.0
    for batch in tqdm(test_loader, desc="Testing"):
        x, y = batch
        x, y = x, y
        y_hat = model(x)
        loss = criterion(y_hat, y)
        test_loss += loss.detach().cpu().item() / len(test_loader)

        correct += torch.sum(torch.argmax(y_hat, dim=1) == y).detach().cpu().item()
        total += len(x)
    print(f"Test loss: {test_loss:.2f}")
    print(f"Test accuracy: {correct / total * 100:.2f}%")
# Out:
# Testing: 100%|██████████| 79/79 [00:28<00:00,  2.74it/s]
# Test loss: 1.98
# Test accuracy: 47.92%

# %%
import h5py 
from functools import reduce
def hdf5(path, data_key = "data", target_key = "target", flatten = True):

    with h5py.File(path, 'r') as hf:
        train = hf.get('train')
        X_tr = train.get(data_key)[:]
        y_tr = train.get(target_key)[:]
        test = hf.get('test')
        X_te = test.get(data_key)[:]
        y_te = test.get(target_key)[:]
        if flatten:
            X_tr = X_tr.reshape(X_tr.shape[0], reduce(lambda a, b: a * b, X_tr.shape[1:]))
            X_te = X_te.reshape(X_te.shape[0], reduce(lambda a, b: a * b, X_te.shape[1:]))
    
    return X_tr, y_tr, X_te, y_te

# %%
X_usps_tr, y_usps_tr, X_usps_te, y_usps_te = hdf5("/content/drive/MyDrive/usps.h5")
X_usps_tr.shape, X_usps_te.shape
# Out:
# ((7291, 256), (2007, 256))

# %%
num_samples = 10
num_classes = len(set(y_usps_tr))
usps_samples = []

classes = set(y_usps_tr)
num_classes = len(classes)
#fig, ax = plt.subplots(num_samples, num_classes, sharex = True, sharey = True, figsize=(num_classes, num_samples))

for label in range(num_classes):
    class_idxs = np.where(y_usps_tr == 8)
    for i, idx in enumerate(np.random.randint(0, class_idxs[0].shape[0], num_samples)):
        tmp = Image.fromarray(X_usps_tr[class_idxs[0][idx]]*255)
        tmp = tmp.resize((32,32), resample=Image.Resampling.BICUBIC)
        tmp = np.array(tmp, dtype=np.uint8)
        tmp[tmp==0] = 1
        usps_samples.append(tmp)

# %%
usps_samples = np.asarray(usps_samples)
usps_samples.shape
# Out:
# (100, 32, 32)

# %%
SHVN_samples = []
for i in range(mat['X'].T.shape[0]):
    a = mat['X'].T[i]
    a = np.mean(a, axis = 0)
    a.shape

    if (mat['y'][i][0] == 8):
        SHVN_samples.append(a)

SHVN_samples = np.asarray(SHVN_samples)

# %%
import torchvision
import tempfile

MNIST_samples = []

dataset = torchvision.datasets.MNIST(root=tempfile.gettempdir(), download=True,
    train=True,transform=torchvision.transforms.Compose([
        torchvision.transforms.Resize(32), torchvision.transforms.ToTensor()]
    ),
)
test_loader = DataLoader(dataset, shuffle=False, batch_size=1)

for batch in tqdm(test_loader, desc="Testing"):
    x, y = batch
    if(y == 1):
        x = x.detach().numpy()
        x[x==0] = 8
        MNIST_samples.append(x[0][0])
# Out:
# Testing: 100%|██████████| 60000/60000 [00:39<00:00, 1522.21it/s]

# %%
mnist_and_svhn = []

for i in range(100):
    a = MNIST_samples[i] + SHVN_samples[i]
    mnist_and_svhn.append(a)


mnist_and_svhn = np.asarray(mnist_and_svhn)

# %%
len(MNIST_samples)
# Out:
# 5421

# %%
def D_KL(p, q):
    return np.dot(p/np.sum(p),
        (
            np.log(p/np.sum(p))
        ) - 
        (
            np.log(q/np.sum(q))
        )
    )

# %%
for j in range(5):
    a = np.random.permutation(99)
    print("j: ",j, ", D_KL: ", D_KL(SHVN_samples[0].ravel(), SHVN_samples[a[0]].ravel()))
# Out:
# j:  0 , D_KL:  0.05657592523650569
# j:  1 , D_KL:  0.08189516157698828
# j:  2 , D_KL:  0.052518477778733696
# j:  3 , D_KL:  0.07793884591987824
# j:  4 , D_KL:  0.023451813131678594

# %%
for j in range(5):
    a = np.random.permutation(99)
    print("j: ",j, ", D_KL: ", D_KL(SHVN_samples[0].ravel(), usps_samples[a[0]].ravel()))
# Out:
# j:  0 , D_KL:  0.18032699706744665
# j:  1 , D_KL:  0.15732199390189355
# j:  2 , D_KL:  0.15429816198340462
# j:  3 , D_KL:  0.13712380963081827
# j:  4 , D_KL:  0.6869462171453429

# %%
for j in range(5):
    a = np.random.permutation(5000)
    print("j: ",j, ", D_KL: ", D_KL(SHVN_samples[0].ravel(), MNIST_samples[a[0]].ravel()))
# Out:
# j:  0 , D_KL:  0.4147882779542582
# j:  1 , D_KL:  0.3675923524270448
# j:  2 , D_KL:  0.3871402434239573
# j:  3 , D_KL:  0.4075098328203004
# j:  4 , D_KL:  0.41379941282971844

# %%
for j in range(5):
    a = np.random.permutation(100)
    print("j: ",j, ", D_KL: ", D_KL(mnist_and_svhn[0].ravel(), usps_samples[a[0]].ravel()))
# Out:
# j:  0 , D_KL:  0.14980464570514945
# j:  1 , D_KL:  0.11204769197058867
# j:  2 , D_KL:  0.07836818243454427
# j:  3 , D_KL:  0.08433996268387739
# j:  4 , D_KL:  0.24996483835599
